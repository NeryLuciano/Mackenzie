# %% [markdown]
# <a href="https://colab.research.google.com/github/NeryLuciano/Mackenzie/blob/main/Recupera%C3%A7%C3%A3o_da_Informa%C3%A7%C3%A3o_na_Web_e_em_Redes_Sociais_Trilha_02.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install requests
# Out:
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (2.23.0)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests) (2021.10.8)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests) (2.10)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests) (1.24.3)

# %%
import requests
	 
url = 'https://www.petz.com.br/nossas-lojas'	
res = requests.get(url)	
html_page = res.text 
html_page
# Out:
# '\n\n\n\n\n\n\n\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\t<!DOCTYPE html>\n<html lang="pt-br">\n\n\n\n\n\n\n\n\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\n<script>\n\n    function sendAnalyticsMenuClicked(linkUrl, linkTextl) {\n        sendAnalyticsMenuClickedComplete(null, null, null, linkUrl, linkTextl)\n    }\n\n    function sendAnalyticsMenuClickedComplete(menuDepartment, menuCategory, menuSubcategory, linkUrl, linkTextl) {\n        var event = "Menu Clicked"\n\n        var pars = ""\n        if (menuDepartment != null && menuDepartment != \'\')\n            pars += "menuDepartment="+menuDepartment+"&"\n        if (menuCategory != null && menuCategory != \'\')\n            pars += "menuCategory="+menuCategory+"&"\n        if (menuSubcategory != null && menuSubcategory != \'\')\n            pars += "menuSubcategory="+menuSubcategory+"&"\n\n        jQuery.ajax({\n            async: false,\n            dataType: "json",\n            url: ctx + "/sendAnalyticsMenuClicked_Loja.html?" + pars + "linkUrl="+linkUrl+"&linkTextl="+linkTextl+"&ctx="+ctx,\n            success: function(response){\n                analytics.track(event, response);\n            },\n            error: function(response) {\n               console.log(event + " FAILURE " + response)\n            }\n        });\n        return false;\n    }\n\n    function sendAnalyticsCartContinued() {\n        var pedidoId = ""\n        var event = "Cart Continued"\n\n        jQuery.ajax({\n            async: false,\n            dataType: "json",\n            url: ctx + "/sendAnalyticsCartContinued_Loja.html?pedidoId="+pedidoId,\n            success: function(response){\n                analytics.track(event, response);\n            },\n            error: function(response) {\n               console.log(event + " FAILURE " + response)\n            }\n        });\n        return false;\n    }\n\n    function sendAnalyticsHeaderClicked (element) {\n        var event = "Header Clicked"\n\n        jQuery.ajax({\n            async: false,\n            dataType: "json",\n            url: ctx + "/sendAnalyticsHeaderClicked_Loja.html?element="+element,\n            success: function(response){\n                analytics.track(event, response);\n            },\n            error: function(response) {\n               console.log(event + " FAILURE " + response)\n            }\n        });\n\n        return false;\n    }\n\n    function sendAnalyticsSearchClicked(element) {\n        let event = "Search Clicked";\n        jQuery.ajax({\n            async: false,\n            dataType: "json",\n            url: ctx + "/sendAnalyticsSearchClicked_Loja.html?element="+element,\n            success: function(response) {\n                analytics.track(event, response);\n            },\n            error: function(response) {\n                console.log(event + " FAILURE " + response)\n            }\n        });\n        return false;\n    }\n\n    function sendAnalyticsProductCart(produtoId, pedidoId, event, oldValue, newValue, element) {\n        jQuery.ajax({\n            async: false,\n            dataType: "json",\n            url: ctx + "/sendAnalyticsProductCart_Loja.html?produtoId="+produtoId+"&pedidoId="+pedidoId+"&oldValue="+oldValue+"&newValue="+newValue+"&element="+element,\n            success: function(response){\n                analytics.track(event, response);\n            },\n            error: function(response) {\n               console.log(event + " FAILURE " + response)\n            }\n        });\n        return false;\n    }\n\n    function sendAnalyticsIndentify() {\n        jQuery.ajax({\n            async: false,\n            dataType: "json",\n            url: ctx + "/sendAna ...

# %%
from bs4 import BeautifulSoup	 
soup = BeautifulSoup(html_page, 'html.parser') 
soup
# Out:
# <!DOCTYPE html>
#
# <html lang="pt-br">
# <script>
#
#     function sendAnalyticsMenuClicked(linkUrl, linkTextl) {
#         sendAnalyticsMenuClickedComplete(null, null, null, linkUrl, linkTextl)
#     }
#
#     function sendAnalyticsMenuClickedComplete(menuDepartment, menuCategory, menuSubcategory, linkUrl, linkTextl) {
#         var event = "Menu Clicked"
#
#         var pars = ""
#         if (menuDepartment != null && menuDepartment != '')
#             pars += "menuDepartment="+menuDepartment+"&"
#         if (menuCategory != null && menuCategory != '')
#             pars += "menuCategory="+menuCategory+"&"
#         if (menuSubcategory != null && menuSubcategory != '')
#             pars += "menuSubcategory="+menuSubcategory+"&"
#
#         jQuery.ajax({
#             async: false,
#             dataType: "json",
#             url: ctx + "/sendAnalyticsMenuClicked_Loja.html?" + pars + "linkUrl="+linkUrl+"&linkTextl="+linkTextl+"&ctx="+ctx,
#             success: function(response){
#                 analytics.track(event, response);
#             },
#             error: function(response) {
#                console.log(event + " FAILURE " + response)
#             }
#         });
#         return false;
#     }
#
#     function sendAnalyticsCartContinued() {
#         var pedidoId = ""
#         var event = "Cart Continued"
#
#         jQuery.ajax({
#             async: false,
#             dataType: "json",
#             url: ctx + "/sendAnalyticsCartContinued_Loja.html?pedidoId="+pedidoId,
#             success: function(response){
#                 analytics.track(event, response);
#             },
#             error: function(response) {
#                console.log(event + " FAILURE " + response)
#             }
#         });
#         return false;
#     }
#
#     function sendAnalyticsHeaderClicked (element) {
#         var event = "Header Clicked"
#
#         jQuery.ajax({
#             async: false,
#             dataType: "json",
#             url: ctx + "/sendAnalyticsHeaderClicked_Loja.html?element="+element,
#             success: function(response){
#                 analytics.track(event, response);
#             },
#             error: function(response) {
#                console.log(event + " FAILURE " + response)
#             }
#         });
#
#         return false;
#     }
#
#     function sendAnalyticsSearchClicked(element) {
#         let event = "Search Clicked";
#         jQuery.ajax({
#             async: false,
#             dataType: "json",
#             url: ctx + "/sendAnalyticsSearchClicked_Loja.html?element="+element,
#             success: function(response) {
#                 analytics.track(event, response);
#             },
#             error: function(response) {
#                 console.log(event + " FAILURE " + response)
#             }
#         });
#         return false;
#     }
#
#     function sendAnalyticsProductCart(produtoId, pedidoId, event, oldValue, newValue, element) {
#         jQuery.ajax({
#             async: false,
#             dataType: "json",
#             url: ctx + "/sendAnalyticsProductCart_Loja.html?produtoId="+produtoId+"&pedidoId="+pedidoId+"&oldValue="+oldValue+"&newValue="+newValue+"&element="+element,
#             success: function(response){
#                 analytics.track(event, response);
#             },
#             error: function(response) {
#                console.log(event + " FAILURE " + response)
#             }
#         });
#         return false;
#     }
#
#     function sendAnalyticsIndentify() {
#         jQuery.ajax({
#             async: false,
#             dataType: "json",
#             url: ctx + "/sendAnalyticsAnonymousIndentify_Loja.html",
#             success: function(response){
#                 analytics.identify(response.cpf, {address: response.address, birthday: response.birthday, email: response.email, name: response.name});
#             },
#              error: function(response) {
#                 console.log(event + " FAILURE sendAnalyticsIndentify" + response)
#              }
#         });
#         return false;
#     }
#
#     function sendAnalyticsProductClick(obj, produtoId, element) {
# 	    var produtoId = produtoId
# 	    var pedidoId = ""
#         var qntd = jQuery(obj).data("qntd")
#
#         sendAnalyticsProductCart(produtoId, pedidoId, "Product Clicked", "1", "1", element);
# 	}
#
#     function sendAnalyticsProductCheckout(produtoId, pedidoId, event, oldValue, newValue) {
#         jQuery.ajax({
#             async: false,
#             dataType: "json",
#             url: ctx + "/sendAnalyticsProductCart_Loja.html?produtoId="+produtoId+"&pedidoId="+pedidoId+"&oldValue="+oldValue+"&newValue="+newValue,
#             success: function(response){
#                 analytics.track(event, response);
#             },
#             error: function(response) {
#                console.log(event + " FAILURE " + response)
#             }
#         });
#         return false;
#     }
#
#     function sendAnalyticsProductViewVariations(produtoId, event){
#         jQuery.ajax({
#             async: false,
#             dataType: "json",
#             url: ctx + "/sendAnalyticsProductViewVariations_Loja.html?produtoId="+produtoId,
#             success: function(response){
#                 analytics.track(event, response);
#             },
#             error: function(response) {
#                console.log(event + " FAILURE " + response)
#             }
#         });
#         return false;
#     }
#
#     function sendAnalyticsCouponCart(event) {
#         let orderId = "";
#         jQuery.ajax({
#             async: false,
#             dataType: "json",
#             url: ctx + "/sendAnalyticsCouponCart_Loja.html?orderId="+orderId,
#             success: function(response){
#                 analytics.track(event, response);
#             },
#             error: function(response) {
#                 console.log(event + " FAILURE " + response)
#             }
#         });
#         return false;
#     }
#
#     function sendAnalyticsShippingEntered(event) {
#         jQuery.ajax({
#             async: false,
#             dataType: "json",
#             url: ctx + "/sendAnalyticsShippingEntered_Loja.html",
#             success: function(response){
#                 analytics.track(event, response);
#             },
#             error: function(response) {
#                 console.log(event + " FAILURE " + response)
#             }
#         });
#         return false;
#     }
#
#     function sendAnalyticsShippingDenied(event, reason) {
#         jQuery.ajax({
#             async: false,
#             dataType: "json",
#             url: ctx + "/sendAnalyticsShippingDenied_Loja.html?reason="+reason,
#             success: function(response){
#                 analytics.track(event, response);
#             },
#             error: function(response) {
#                 console.log(event + " FAILURE " + response)
#             }
#         });
#         return false;
#     }
#
#     function sendAnalyticsShippingApplied(event, selected) {
#         let orderId = "";
#         jQuery.ajax({
#             async: false,
#             dataType: "json",
#             url: ctx + "/sendAnalyticsShippingApplied_Loja.html?selected="+selected+"&orderId"+orderId,
#             success: function(response){
#                 analytics.track(event, response);
#             },
#             error: function(response) {
#                 console.log(event + " FAILURE " + response)
#             }
#         });
#         return false;
#     }
# </script>
# <head>
# <meta charset="utf-8"/>
# <meta content="width=device-width, initial-scale=1, maximum-scale=5" name="viewport"/>
# <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
# <!-- meta name="google-site-verification" content="kxsAfYOJrOEBIfR84x6tO0F3kgs2X28RXAuAx7lbUWQ" -->
# <meta content="_wDqq17AH_FSdSdlS-D3Zl_vwEkAAWt--CWr6-bRGdY" name="google-site-verification"/>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <meta content="pt-BR" name="language"/>
# <meta content="BRA" name="country"/>
# <meta content="R$" name="currency"/>
# <meta content="Petz - Seu pet center de estimação" name="Abstract"/>
# <meta content="Petz" name="author"/>
# <meta content="Petz" name="copyright"/>
# <meta content="!" name="fragment"/>
# <meta content="on" http-equiv="x-dns-prefetch-control"/>
# <meta content="" name="keywords"/>
# <meta content="width=device-width,initial-scale=1,maximum-scale=5,user-scalable=yes" name="viewport"/>
# <link crossorigin="anonymous" href="http://event.getblue.io/" rel="preconnect"/>
# <link href="http://ib.adnxs.com/" rel="preconnect"/>
# <link href="http://static.criteo.net/" rel="preconnect"/>
# <link href="http://targeting.voxus.com.br/" rel="preconnect"/>
# <link href="http://tracking.i-goal.com.br/" rel="preconnect"/>
# <link crossorigin="anonymous" href="http://www.googletagmanager.com/" rel="preconnect"/>
# <link href="http://us.creativecdn.com/" rel="preconnect"/>
# <link href="https://ajax.cloudflare.com/" rel="preconnect"/>
# <link href="https://ash.creativecdn.com/" rel="preconnect"/>
# <link href="https://assets.jetlore.com/" rel="preconnect"/>
# <link href="https://connect.facebook.net/" rel="preconnect"/>
# <link href="https://files.directtalk.com.br/" rel="preconnect"/>
# <link crossorigin="anonymous" href="https://js.appboycdn.com/" rel="preconnect">
# <link crossorigin="anonymous" href="https://script.hotjar.com/" rel="preconnect">
# <link href="https://secure.adnxs.com/" rel="preconnect">
# <link crossorigin="anonymous" href="https://static.r-mkt.com/" rel="preconnect">
# <link href="https://tracking.i-goal.com.br/" rel="preconnect">
# <link href="https://vars.hotjar.com/" rel="preconnect">
# <link crossorigin="anonymous" href="https://voxus-targeting-voxusmidia.netdna-ssl.com/" rel="preconnect">
# <link href="https://www.google-analytics.com/" rel="preconnect">
# <link crossorigin="anonymous" href="https://www.googletagmanager.com/" rel="preconnect">
# <meta content="#136CB3" name="theme-color"/>
# <meta content="https://staticpetz.stoom.com.br/images/logo.png" property="og:image"/>
# <title>Nossas Lojas | Petz</title>
# <link href="https://www.petz.com.br/novaLoja/images/icon.png" rel="icon" type="image/png">
# <link href="https://www.petz.com.br/nossas-lojas" media="only screen and (max-width: 640px)" rel="alternate">
# <link href="/manifest.json" rel="manifest">
# <!-- HTML5 shim and Respond.js for IE8 support of HTML5 elements and media queries -->
# <!-- WARNING: Respond.js doesn't work if you view the page via file:// -->
# <!--[if lt IE 9]>
# 		<script src="https://oss.maxcdn.com/html5shiv/3.7.2/html5shiv.min.js" type="text/javascript"></script>
# 		<script src="https://oss.maxcdn.com/respond/1.4.2/respond.min.js" type="text/javascript"></script>
# 	<![endif]-->
# <script type="text/javascript">
#
# 			var dominioWeb = "petz.com.br";
#
#
# 		var isHomeMobile = false
# 	</script>
# <script type="application/ld+json">
#  	{
#     	"@context": "http://schema.org",
#     	"@type": "WebSite",
#     	"url": "https://www.petz.com.br",
#     	"image": "https://staticpetz.stoom.com.br/novaLoja/images/logo.png",
#     	"potentialAction": {
#     		"@type": "SearchAction",
#     		"target": "https://www.petz.com.br/busca?q={search_term_string}",
#     		"query-input": "required name=search_term_string"
#     	},
#     	"sameAs": [
#     		"https://www.youtube.com/petztube",
#     		"https://www.facebook.com/petzbr",
#     		"https://www.instagram.com/somospetz"
#     	]
# 	}
# 	</script>
# <link href="https://www.petz.com.br/novaLoja/styles/external-styles.css?noCache=20190704" rel="stylesheet"/>
# <link href="https://www.petz.com.br/novaLoja/styles/style.css?noCache=20190704" rel="stylesheet" type="text/css"/>
# <link href="https://www.petz.com.br/novaLoja/styles/petz.css?noCache=20190704" rel="stylesheet" type="text/css"/>
# <link href="https://www.petz.com.br/novaLoja/styles/style-newSass.min.css?noCache=20190704" rel="stylesheet" type="text/css"/>
# <style>.autocomplete-suggestions{min-width:calc(100% - 34px);background:#f9f9f9;overflow:auto;border:1px solid #f9f9f9;border-top:0;border-bottom-left-radius:8px;border-bottom-right-radius:8px;padding:6px;z-index:99999!important}.autocomplete-suggestion{padding:2px 5px;white-space:nowrap;overflow:hidden}.autocomplete-suggestion:hover{color:#126ab2;cursor:pointer}.autocomplete-selected{background:#F0F0F0}.autocomplete-group{padding:2px 5px}
# </style>
# <script src="https://www.petz.com.br/novaLoja/scripts/external-scripts.js?noCache=20190704" type="text/javascript"></script>
# <script src="https://www.petz.com.br/novaLoja/scripts/app.js?noCache=20190704" type="text/javascript"></script>
# <script src="https://www.petz.com.br/novaLoja/scripts/globalLoja.js?noCache=20190704" type="text/javascript"></script>
# <script src="https://www.petz.com.br/novaLoja/scripts/requisicoesAjax.js?noCache=20190704" type="text/javascript"></script>
# <link as="font" crossorigin="" href="https://www.petz.com.br/fonts/icomoon.woff?kv8bh7" rel="preload" type="font/woff"/>
# <style>
# 			*{-webkit-box-sizing:border-box;-moz-box-sizing:border-box;box-sizing:border-box}:after,:before{-webkit-box-sizing:border-box;-moz-box-sizing:border-box;box-sizing:border-box}html{font-size:10px;-ms-text-size-adjust:100%;-webkit-text-size-adjust:100%;-webkit-tap-highlight-color:rgba(0,0,0,0)}body{margin:0;font-size:14px;line-height:1.42857143;color:#333;background-color:#fff}article,aside,details,figcaption,figure,footer,header,hgroup,main,menu,nav,section,summary{display:block}a{background-color:transparent;color:#337ab7;text-decoration:none}b,strong{font-weight:700}img{border:0;vertical-align:middle}button,input,optgroup,select,textarea{color:inherit;font:inherit;margin:0;font-family:inherit;font-size:inherit;line-height:inherit}button{overflow:visible}button,select{text-transform:none}button,html input[type=button],input[type=reset],input[type=submit]{-webkit-appearance:button;cursor:pointer}input{line-height:normal}input[type=search]{-webkit-appearance:textfield;-webkit-box-sizing:content-box;-moz-box-sizing:content-box;box-sizing:content-box}input[type=search]::-webkit-search-cancel-button,input[type=search]::-webkit-search-decoration{-webkit-appearance:none}textarea{overflow:auto}table{border-collapse:collapse;border-spacing:0}.h1,.h2,.h3,.h4,.h5,.h6,h1,h2,h3,h4,h5,h6{font-family:inherit;font-weight:500;line-height:1.1;color:inherit}.h1,.h2,.h3,h1,h2,h3{margin-top:20px;margin-bottom:10px}.h2,h2{font-size:30px}.h3,h3{font-size:24px}p{margin:0 0 10px}ol,ul{margin-top:0;margin-bottom:10px}ol ol,ol ul,ul ol,ul ul{margin-bottom:0}label{display:inline-block;max-width:100%;margin-bottom:5px;font-weight:700}input[type=search]{-webkit-box-sizing:border-box;-moz-box-sizing:border-box;box-sizing:border-box;-webkit-appearance:none;-moz-appearance:none;appearance:none}.text-center{text-align:center}.container{padding-right:15px;padding-left:15px;margin-right:auto;margin-left:auto}.row{margin-right:-15px;margin-left:-15px}.col-lg-1,.col-lg-10,.col-lg-11,.col-lg-12,.col-lg-2,.col-lg-3,.col-lg-4,.col-lg-5,.col-lg-6,.col-lg-7,.col-lg-8,.col-lg-9,.col-md-1,.col-md-10,.col-md-11,.col-md-12,.col-md-2,.col-md-3,.col-md-4,.col-md-5,.col-md-6,.col-md-7,.col-md-8,.col-md-9,.col-sm-1,.col-sm-10,.col-sm-11,.col-sm-12,.col-sm-2,.col-sm-3,.col-sm-4,.col-sm-5,.col-sm-6,.col-sm-7,.col-sm-8,.col-sm-9,.col-xs-1,.col-xs-10,.col-xs-11,.col-xs-12,.col-xs-2,.col-xs-3,.col-xs-4,.col-xs-5,.col-xs-6,.col-xs-7,.col-xs-8,.col-xs-9{position:relative;min-height:1px;padding-right:15px;padding-left:15px}.form-control{display:block;width:100%;height:34px;padding:6px 12px;font-size:14px;line-height:1.42857143;color:#555;background-color:#fff;background-image:none;border:1px solid #ccc;border-radius:4px;-webkit-box-shadow:inset 0 1px 1px rgba(0,0,0,0.075);box-shadow:inset 0 1px 1px rgba(0,0,0,0.075);-webkit-transition:border-color ease-in-out .15s,box-shadow ease-in-out .15s;-o-transition:border-color ease-in-out .15s,box-shadow ease-in-out .15s;-webkit-transition:border-color ease-in-out .15s,-webkit-box-shadow ease-in-out .15s;transition:border-color ease-in-out .15s,-webkit-box-shadow ease-in-out .15s;transition:border-color ease-in-out .15s,box-shadow ease-in-out .15s;transition:border-color ease-in-out .15s,box-shadow ease-in-out .15s,-webkit-box-shadow ease-in-out .15s}.form-control::-webkit-input-placeholder{color:#999}.fade{opacity:0;-webkit-transition:opacity .15s linear;-o-transition:opacity .15s linear;transition:opacity .15s linear}footer.footer-desktop-cart{background-color:#FFF}.container-fluid footer{margin-left:-15px;margin-right:-15px}footer .holder-newsletter{background-color:#F5F5F5;border-radius:10px !important;box-shadow:0 1px 0 #E5E5E5}footer ul{padding:0;margin:0}footer ul li{line-height:32px;list-style:none}footer a{color:#444;text-decoration:none;font-weight:normal;cursor:pointer}footer .brand{background:url("https://staticpetz.stoom.com.br/novaLoja/images/brands.png") no-repeat;flex-grow:0 !important;min-width:32px;min-height:32px;display: ...
#
# 		</style>
# <!-- Google Analytics Content Experiment code -->
# <script>
# 			var usarSegment = false;
#
# 			if(usarSegment){
# 				function utmx_section(){}function utmx(){}(function(){var
# 				k='96654356-15',d=document,l=d.location,c=d.cookie;
# 				if(l.search.indexOf('utm_expid='+k)>0)return;
# 				function f(n){if(c){var i=c.indexOf(n+'=');if(i>-1){var j=c.
# 				indexOf(';',i);return escape(c.substring(i+n.length+1,j<0?c.
# 				length:j))}}}var x=f('__utmx'),xx=f('__utmxx'),h=l.hash;d.write(
# 				'<sc'+'ript src="'+'http'+(l.protocol=='https:'?'s://ssl':
# 				'://www')+'.google-analytics.com/ga_exp.js?'+'utmxkey='+k+
# 				'&utmx='+(x?x:'')+'&utmxx='+(xx?xx:'')+'&utmxtime='+new Date().
# 				valueOf()+(h?'&utmxhash='+escape(h.substr(1)):'')+
# 				'" type="text/javascript" charset="utf-8"><\/sc'+'ript>')})();
#
# 				utmx('url','A/B');
# 			}
# 		</script>
# <!-- End of Google Analytics Content Experiment code -->
# <script type="text/javascript">
# 	var usarSegment = false;
#     if(usarSegment){
# 		(function(i,s,o,g,r,a,m){i['GoogleAnalyticsObject']=r;i[r]=i[r]||function(){
# 		(i[r].q=i[r].q||[]).push(arguments)},i[r].l=1*new Date();a=s.createElement(o),
# 		m=s.getElementsByTagName(o)[0];a.async=1;a.src=g;m.parentNode.insertBefore(a,m)
# 		})(window,document,'script','//www.google-analytics.com/analytics.js','ga');
#
# 		ga('create', 'UA-58792402-1', 'auto');
# 		ga('require', 'linkid', 'linkid.js'); // GA: atribuicao melhorada de link
# 		ga('require', 'displayfeatures');
# 		ga('send', 'pageview');
#
#
# 	}
# 	</script>
# <meta content="O seu Pet Center de estimação sempre está do seu lado! Conheça todas as nossas lojas e veja qual é a unidade mais próxima de você! Entre e confira!" name="description"/>
# <script type="text/javascript">(window.NREUM||(NREUM={})).init={privacy:{cookies_enabled:false},ajax:{deny_list:["bam-cell.nr-data.net"]},distributed_tracing:{enabled:true,allowed_origins:[]}};(window.NREUM||(NREUM={})).loader_config={agentID:"71652389",accountID:"1669273",trustKey:"1669273",xpid:"VQABWFRUCxAHVVdXBgUFUg==",licenseKey:"cdc8fc4c06",applicationID:"71651424"};window.NREUM||(NREUM={}),__nr_require=function(t,e,n){function r(n){if(!e[n]){var o=e[n]={exports:{}};t[n][0].call(o.exports,function(e){var o=t[n][1][e];return r(o||e)},o,o.exports)}return e[n].exports}if("function"==typeof __nr_require)return __nr_require;for(var o=0;o<n.length;o++)r(n[o]);return r}({1:[function(t,e,n){function r(t){try{s.console&&console.log(t)}catch(e){}}var o,i=t("ee"),a=t(32),s={};try{o=localStorage.getItem("__nr_flags").split(","),console&&"function"==typeof console.log&&(s.console=!0,o.indexOf("dev")!==-1&&(s.dev=!0),o.indexOf("nr_dev")!==-1&&(s.nrDev=!0))}catch(c){}s.nrDev&&i.on("internal-error",function(t){r(t.stack)}),s.dev&&i.on("fn-err",function(t,e,n){r(n.stack)}),s.dev&&(r("NR AGENT IN DEVELOPMENT MODE"),r("flags: "+a(s,function(t,e){return t}).join(", ")))},{}],2:[function(t,e,n){function r(t,e,n,r,s){try{l?l-=1:o(s||new UncaughtException(t,e,n),!0)}catch(f){try{i("ierr",[f,c.now(),!0])}catch(d){}}return"function"==typeof u&&u.apply(this,a(arguments))}function UncaughtException(t,e,n){this.message=t||"Uncaught error with no additional information",this.sourceURL=e,this.line=n}function o(t,e){var n=e?null:c.now();i("err",[t,n])}var i=t("handle"),a=t(33),s=t("ee"),c=t("loader"),f=t("gos"),u=window.onerror,d=!1,p="nr@seenError";if(!c.disabled){var l=0;c.features.err=!0,t(1),window.onerror=r;try{throw new Error}catch(h){"stack"in h&&(t(14),t(13),"addEventListener"in window&&t(7),c.xhrWrappable&&t(15),d=!0)}s.on("fn-start",function(t,e,n){d&&(l+=1)}),s.on("fn-err",function(t,e,n){d&&!n[p]&&(f(n,p,function(){return!0}),this.thrown=!0,o(n))}),s.on("fn-end",function(){d&&!this.thrown&&l>0&&(l-=1)}),s.on("internal-error",function(t){i("ierr",[t,c.now(),!0])})}},{}],3:[function(t,e,n){var r=t("loader");r.disabled||(r.features.ins=!0)},{}],4:[function(t,e,n){function r(){U++,L=g.hash,this[u]=y.now()}function o(){U--,g.hash!==L&&i(0,!0);var t=y.now();this[h]=~~this[h]+t-this[u],this[d]=t}function i(t,e){E.emit("newURL",[""+g,e])}function a(t,e){t.on(e,function(){this[e]=y.now()})}var s="-start",c="-end",f="-body",u="fn"+s,d="fn"+c,p="cb"+s,l="cb"+c,h="jsTime",m="fetch",v="addEventListener",w=window,g=w.location,y=t("loader");if(w[v]&&y.xhrWrappable&&!y.disabled){var x=t(11),b=t(12),E=t(9),R=t(7),O=t(14),T=t(8),P=t(15),S=t(10),M=t("ee"),N=M.get("tracer"),C=t(23);t(17),y.features.spa=!0;var L,U=0;M.on(u,r),b.on(p,r),S.on(p,r),M.on(d,o),b.on(l,o),S.on(l,o),M.buffer([u,d,"xhr-resolved"]),R.buffer([u]),O.buffer(["setTimeout"+c,"clearTimeout"+s,u]),P.buffer([u,"new-xhr","send-xhr"+s]),T.buffer([m+s,m+"-done",m+f+s,m+f+c]),E.buffer(["newURL"]),x.buffer([u]),b.buffer(["propagate",p,l,"executor-err","resolve"+s]),N.buffer([u,"no-"+u]),S.buffer(["new-jsonp","cb-start","jsonp-error","jsonp-end"]),a(T,m+s),a(T,m+"-done"),a(S,"new-jsonp"),a(S,"jsonp-end"),a(S,"cb-start"),E.on("pushState-end",i),E.on("replaceState-end",i),w[v]("hashchange",i,C(!0)),w[v]("load",i,C(!0)),w[v]("popstate",function(){i(0,U>1)},C(!0))}},{}],5:[function(t,e,n){function r(){var t=new PerformanceObserver(function(t,e){var n=t.getEntries();s(v,[n])});try{t.observe({entryTypes:["resource"]})}catch(e){}}function o(t){if(s(v,[window.performance.getEntriesByType(w)]),window.performance["c"+p])try{window.performance[h](m,o,!1)}catch(t){}else try{window.performance[h]("webkit"+m,o,!1)}catch(t){}}function i(t){}if(window.performance&&window.performance.timing&&window.performance.getEntriesByType){var a=t("ee"),s=t("handle"),c=t(14),f=t(13),u=t(6),d=t(23),p="learResourceTimings",l="addEventListener",h="removeEventListener",m="resourcetimingbufferfull",v="bstResource",w="resource",g="-st ...
# <script src="https://www.petz.com.br/plugins/jquery.mask/jquery.mask.min.js"></script>
# <script>window.petz = { ajax: "" }</script>
# <style>
#         .banner {
#             background: #ffffff  url('/fotos/') no-repeat center center;
#         }
#         .container-fluid {
#             padding-top: 0;
#         }
# 	</style>
# <link href="https://fonts.googleapis.com/icon?family=Material+Icons" rel="stylesheet"/>
# <link href="https://www.petz.com.br/novaLoja/styles/storeList.css" rel="stylesheet" type="text/css">
# <script type="text/javascript">
# 		document.addEventListener("DOMContentLoaded", function(event) {
# 			jQuery(function(){
# 				jQuery("#search").autocomplete({
# 					serviceUrl: 'https://petz-subservices.stoom.com.br/buscaAutoComplete_Loja.html',
# 					onSelect: function (suggestion) {
# 						//  alert('You selected: ' + suggestion.value + ', ' + suggestion.data);
# 				     	jQuery("#search").parents("form").submit();
# 					}
# 				});
# 			});
# 		});
#
# 	</script>
# <script async="" type="text/javascript">
#        if(typeof pageTypeDefault === "undefined"){
#            pageTypeDefault = "";
#        }
#        var str = window.location.pathname;
#         str = str.split("/");
#         var pageName = str[str.length - 1];
#         if(pageName === ""){
#             pageName = "Home"
#         }
#         var usarSegment = true;
#         if(usarSegment){
#             !function(){var analytics=window.analytics=window.analytics||[];if(!analytics.initialize)if(analytics.invoked)window.console&&console.error&&console.error("Segment snippet included twice.");else{analytics.invoked=!0;analytics.methods=["trackSubmit","trackClick","trackLink","trackForm","pageview","identify","reset","group","track","ready","alias","debug","page","once","off","on"];
#             analytics.factory=function(t){return function(){var e=Array.prototype.slice.call(arguments);e.unshift(t);
#             analytics.push(e);return
#             analytics}};for(var t=0;t<analytics.methods.length;t++){var e=analytics.methods[t];analytics[e]=analytics.factory(e)}analytics.load=function(t,e){var n=document.createElement("script");n.type="text/javascript";n.async=!0;n.src="https://cdn.segment.com/analytics.js/v1/"+t+"/analytics.min.js";var a=document.getElementsByTagName("script")[0];a.parentNode.insertBefore(n,a);
#             analytics._loadOptions=e};
#             analytics.SNIPPET_VERSION="4.1.0";
#             analytics.load("x7a5ftBXuhYuVkSO32T4PTWpZRv0EESp");
#             analytics.ready(function() {
#              window.analytics.page(pageName,{type: pageTypeDefault});
#             });
#             }}();
#         }
#      </script>
# <script async="" type="text/javascript">
#      		document.addEventListener("DOMContentLoaded", function(event) {
#      		var usarSegment = true;
#                 if(usarSegment){
#      		    	var hasAnonymousId = false;
#
#                     if (!hasAnonymousId) {
#                         var segmentAnonymousId = analytics.user().anonymousId();
#                         jQuery.ajax({
#                           type: 'POST',
#                           url: ctx + "/setSegmentAnonymousId_Loja.html?segmentAnonymousId="+segmentAnonymousId,
#                           success: function(response) { return true; }
#                         });
#                     }
#                 }
#      		});
#      </script>
# <link href="https://fonts.gstatic.com" rel="preconnect"/>
# <link href="https://fonts.googleapis.com/css2?family=Roboto:wght@300;400;500;700;900&amp;display=fallback" rel="stylesheet"/>
# </link></link></link></link></link></link></link></link></link></link></link></link></link></head>
# <body itemscope="" itemtype="http://schema.org/PetStore">
# <meta content="https://www.petz.com.br" itemprop="url"/>
# <meta content="Petz - Pet Shop Online" itemprop="name"/>
# <meta content="https://www.petz.com.br/novaLoja/images/logo.png" itemprop="image"/>
# <div class="modal fade" id="popupLock" role="dialog">
# <div class="modal-dialog">
# <div class="modal-content lock-modal">
# <div class="modal-header petz_modal_header">
# <img alt="Relógio" src="https://www.petz.com.br/images/lojav3/clock.png" title="Relógio"/>
# <div class="titleDiv" id="lockMPTitle"><b>Isso, agora estamos <br/> processando seu pagamento...</b></div>
# </div>
# <div class="modal-body petz-modal">
# 				Aguarde um momento... Por favor, <b>não</b> recarregue a página,
# 				<b>não</b> clique em voltar e <b>não</b> feche a tela. Já, já seu pedido será realizado!
# 			</div>
# </div>
# </div>
# </div>
# <a data-toggle="modal" onclick="jQuery('#popupLock').modal('show');"></a>
# <script type="text/javascript">
# 	function showPopupLock(){
# 		jQuery('#popupLock').on('hide.bs.modal', function (e){return e.preventDefault();});
# 		jQuery("#popupLock").modal();
# 	}
# 	function hidePopupLock(){
# 		jQuery("#popupLock").unbind("hide.bs.modal");
# 		jQuery("#popupLock").modal("hide");
# 	}
#
# </script>
# <!-- Modal -->
# <div class="modal fade" id="popupAtendimento" role="dialog">
# <div class="modal-dialog">
# <div class="modal-content">
# <div class="modal-header petz_modal_header">
# <button aria-hidden="true" class="close" data-dismiss="modal" type="button">×</button>
# <div class="modal-title">Fale Conosco</div>
# </div>
# <div class="modal-body petz-modal">
# <div class="social-icons-conatainer">
# <div class="modal-body">
# <p><b>Horário de atendimento:</b><br> De segunda a sexta das 9h às 18h e aos sábados das 10h às 16h (exceto feriados).</br></p>
# <p><b>Atendimento Loja Virtual:</b> <span itemprop="telephone">(11) 3434-6980</span></p>
# <a class="atendimentoTelefones btn modal-petz-btn" data-toggle="modal" href="/nossas-lojas">
# <i class="fa fa-phone"></i> Telefone das Nossas Lojas
# 						</a>
# <a class="btn modal-petz-btn" data-toggle="modal" id="NeoassistOpenEMail">Enviar e-mail</a>
# </div>
# </div>
# <div class="clearfix"></div>
# </div>
# <div class="clearfix"></div>
# </div>
# </div>
# </div>
# <!-- Modal -->
# <div class="modal fade newAlert novoPopup" id="popupOuvidoria" role="dialog">
# <div class="modal-dialog">
# <div class="modal-content">
# <div class="modal-header petz_modal_header">
# <button aria-hidden="true" class="close" data-dismiss="modal" type="button">×</button>
# <div class="modal-title">Ouvidoria</div>
# </div>
# <div class="modal-body petz-modal">
# <div class="social-icons-conatainer">
# <div class="modal-body">
# <div class="text-container">
# <p>Olá, seja bem-vindo(a) ao canal da Ouvidoria da Petz. Nossa equipe está disponível para atender você e garantir que receba o melhor atendimento.</p>
# <p>Caso sua manifestação ainda não tenha sido solucionada pelos nossos canais de atendimento tradicionais, Alô Petz e lojas físicas, entre em contato conosco por meio do formulário a seguir que retornaremos o mais breve possível.</p>
# <p><b>Horário de atendimento:</b></p>
# <p>De segunda a quinta das 09hs às 19hs (exceto feriados).</p>
# <p>Sexta-feira das 09hs às 18hs (exceto feriados).</p>
# <p>Telefone: <b><a href="tel:+551134346888">(11) 3434-6888</a></b></p>
# <p><a href="mailto:ouvidoria@petz.com.br"><b>ouvidoria@petz.com.br</b></a></p>
# </div>
# <a class="btn modal-petz-btn" data-toggle="modal" onclick="jQuery('#popupFaleConosco').modal('show');">Enviar e-mail</a>
# </div>
# </div>
# <div class="clearfix"></div>
# </div>
# <div class="clearfix"></div>
# </div>
# </div>
# </div>
# <head>
# <script type="text/javascript">
# 		function callbackAtendimento() {
# 			jQuery('#popupFaleConosco').modal('hide');
# 			jQuery("#loading-enviar").hide();
# 			jQuery("#faleConoscoEnviar ").show();
# 			jQuery("#faleConoscoForm").trigger("reset");
# 		}
# 		document.addEventListener("DOMContentLoaded", function(event) {
# 			jQuery(document).ready(function() {
# 				//jQuery("#telefone").mask("(00) 00000-0000");
# 				jQuery("#faleConoscoEnviar").click(function() {
# 					/*var response = grecaptcha.getResponse();*/
# 					if (jQuery("#faleConoscoForm").find("#nome").val().trim() == "") {
# 						callAlert("Preencha o campo nome");
# 						jQuery("#faleConoscoForm").find("#nome").focus();
# 					}
# 					else if (!validarEmail(jQuery("#faleConoscoForm").find("#email").val())) {
# 						callAlert("Preencha o campo e-mail");
# 						jQuery("#faleConoscoForm").find("#email").focus();
# 					}
# 					else if (jQuery("#faleConoscoForm").find("#telefone").val().trim() == "" || jQuery("#faleConoscoForm").find("#telefone").val().length < 10) {
# 						callAlert("Preencha o campo telefone");
# 						jQuery("#faleConoscoForm").find("#telefone").focus();
# 					}
# 					else if (jQuery("#faleConoscoForm").find("#assunto").val().trim() == "") {
# 						callAlert("Preencha o campo assunto");
# 						jQuery("#faleConoscoForm").find("#assunto").focus();
# 					}
# 					else if (jQuery("#faleConoscoForm").find("#mensagem").val().trim() == "") {
# 						callAlert("Preencha o campo mensagem");
# 						jQuery("#faleConoscoForm").find("#mensagem").focus();
# 					}
# 					// else if (response.length == 0) {
# 					// 	callAlert("Responda ao reCAPTCHA");
# 					// 	jQuery("#recaptcha").find("#g-recaptcha").focus();
# 					// }
# 					else {
# 						jQuery("#faleConoscoEnviar ").hide();
# 						/*grecaptcha.reset();*/
# 						jQuery("#loading-enviar").show();
# 						atendimentoEmail(callbackAtendimento);
# 					}
# 				});
# 			});
# 		});
#
# 		function atendimentoEmail(callback) {
#
# 	var nome = jQuery("#faleConoscoForm").find("#nome").val();
# 	var email = jQuery("#faleConoscoForm").find("#email").val();
# 	var telefone = jQuery("#faleConoscoForm").find("#telefone").val();
# 	var assunto = jQuery("#faleConoscoForm").find("#assunto").val();
# 	var mensagem = jQuery("#faleConoscoForm").find("#mensagem").val();
# 	var ouvidoria = jQuery("#faleConoscoForm").find("#ouvidoria").val();
# 	var urlCompleta = jQuery("#faleConoscoForm").find("#urlCompleta").val();
# 	var cpf = jQuery("#faleConoscoForm").find("#cpf").val();
#
# 	var tel = telefone;
# 	var ddd = "";
#
# 	try {
# 		tel = telefone.substring(telefone.indexOf(" ") + 1);
# 		ddd = telefone.substring(0, telefone.indexOf(" ")).replace("(","").replace(")","");
# 	}
# 	catch(e) {
# 		console.log(e.message);
# 	}
#
# 	var params = {
# 		remetente: nome,
# 		emailAtendimento: email,
# 		assunto: assunto,
# 		"lojaConfig.mensagemEmailLembretePagamento": mensagem,
# 		telefone: tel,
# 		ddd: ddd,
# 		ouvidoria: ouvidoria,
# 		urlCompleta: urlCompleta,
# 		cpf: cpf
# 	};
#
# 	var fields = jQuery("#faleConoscoForm :input").serializeArray();
#
# 	jQuery.ajax({
# 		url: ctx + "/faleConosco_Loja.html",
# 		data: params,
# 		success: function (data){
# 			callAlert("E-mail enviado com sucesso!", undefined, undefined, callback);
# 		}
# 	});
# 	return false;
# }
# 	</script>
# </head>
# <!-- Modal -->
# <div class="modal fade newAlert novoPopup" id="popupFaleConosco" role="dialog">
# <div class="modal-dialog modal-dialog-faleConosco">
# <div class="modal-content">
# <div class="modal-header petz_modal_header">
# <button aria-hidden="true" class="close" data-dismiss="modal" type="button">×</button>
# <div class="modal-title faleConosco-modal-title">atendimento por email</div>
# </div>
# <div class="modal-body petz-modal no-scroll">
# <div class="social-icons-conatainer">
# <div class="modal-body">
# <form id="faleConoscoForm">
# <input name="request_locale" type="hidden" value=""/>
# <input id="ouvidoria" name="ouvidoria" type="hidden" value="true"/>
# <input id="urlCompleta" name="urlCompleta" type="hidden" value="https://www.petz.com.br/nossas-lojas"/>
# <div class="form-group">
# <label for="nome">Nome</label> <input class="form-control login-field" id="nome" type="text" value=""/> <i class="fa fa-user petz-field-icon"></i>
# </div>
# <div class="form-group">
# <label for="email">Email</label> <input class="form-control login-field" id="email" type="text" value=""/> <i class="fa fa-envelope-o petz-field-icon"></i>
# </div>
# <div class="form-group">
# <label for="cpf">CPF</label> <input class="form-control login-field" id="cpf" type="text" value=""/> <i class="fa fa-id-card-o petz-field-icon"></i>
# </div>
# <div class="form-group">
# <label for="telefone">Telefone</label> <input class="form-control login-field" id="telefone" type="text" value=""/> <i class="fa fa-phone petz-field-icon"></i>
# </div>
# <div class="form-group">
# <label for="assunto">Assunto</label>
# <select class="form-control login-field" id="assunto" name="assunto">
# <option value=""></option>
# <option value="Dúvida">Dúvida</option>
# <option value="Elogio">Elogio</option>
# <option value="Reclamação">Reclamação</option>
# <option value="Sugestão">Sugestão</option>
# </select>
# <i class="fa fa-pencil petz-select-icon"></i>
# </div>
# <div class="form-group">
# <label for="mensagem">Mensagem</label>
# <textarea class="form-control login-field" id="mensagem"></textarea>
# </div>
# <div id="enviar">
# <a class="btn modal-petz-btn" href="#" id="faleConoscoEnviar">ENVIAR</a>
# <img alt="Aguarde enquanto enviamos sua mensagem." class="escondido lazyload" data-src="https://www.petz.com.br/novaLoja/images/loading.gif" id="loading-enviar" title="Aguarde enquanto enviamos sua mensagem."/>
# </div>
# </form>
# </div>
# </div>
# <div class="clearfix"></div>
# </div>
# <div class="clearfix"></div>
# </div>
# </div>
# </div>
# <head>
# <script type="text/javascript">
# 		jQuery(document).ready(function() {
# 			var $processingGif = jQuery("#divThrobberCallAlert .processing");
# 			var processingGifUrl = $processingGif.data("src");
# 			$processingGif.attr("src", processingGifUrl);
# 		});
#
# 		function generateId() {
# 		    var S4 = function() {
# 		       return (((1+Math.random())*0x10000)|0).toString(16).substring(1);
# 		    };
# 		    return (S4()+S4()+"-"+S4()+"-"+S4()+"-"+S4()+"-"+S4()+S4()+S4());
# 		}
#
# 		function callAlertHTML(html) {
# 			var template = $(html).get(0);
# 			var id = "callAlert_" + generateId();
# 			$(template).attr("id", id);
# 			$("#callAlertLimbo").append($(template));
# 			id = "#" + id;
# 			$(id).modal("show");
#
# 			message = "<p>".concat(message.concat("</p><br/><br/>"));
#             $(id).find(".modal-message").html(message);
# 		}
#
# 		function closeThrobber(id){
# 			if($(id).size() > 0)
# 			{
# 				$(id).find(".close").click();
# 			}
# 		}
#
# 	    function callThrobber(timeout){
# 	    	var template = $($("#callAlertTemplate").html()).get(0);
#
# 			var id = "callAlert_" + generateId();
# 			$(template).attr("id", id);
# 			$("#callAlertLimbo").append($(template));
#
# 			id = "#" + id;
#
# 			$(id).find(".modal-message").append($("#divThrobberCallAlert div").clone());
#
# 			$(id).find(".modal-title").hide();
# 			$(id).find(".modal-petz-btn.ok").hide();
# 			$(id).find(".close").hide();
# 			$(id).addClass("throbber");
# 			$(id).modal({backdrop: 'static', keyboard: false});
#
# 			setTimeout(function(){ closeThrobber(id); }, timeout == undefined ? 30000 : timeout);
#
# 			return id;
# 	    }
#
# 	    function callThrobberUnload(timeout){
# 	    	var template = $($("#callAlertTemplate").html()).get(0);
#
# 			var id = "callAlert_" + generateId();
# 			$(template).attr("id", id);
# 			$("#callAlertLimbo").append($(template));
#
# 			id = "#" + id;
#
# 			$(id).find(".modal-message").append($("#divThrobberCallAlert div"));
#
# 			$(id).find(".modal-title").hide();
# 			$(id).find(".modal-petz-btn.ok").hide();
# 			$(id).find(".close").hide();
# 			$(id).modal({backdrop: 'static', keyboard: false});
#
# 			setTimeout(function(){ closeThrobber(id); }, timeout == undefined ? 30000 : timeout);
#
# 			return id;
# 	    }
#
# 		function callAlert(message, title, okText, callback, callbackParams, showCancel, cancelText, callbackCancel, callbackCancelParams, cssClass, callbackHide, callbackHideParams) {
# 			var template = $($("#callAlertTemplate").html()).get(0);
#
# 			var id = "callAlert_" + generateId();
#
# 			$(template).attr("id", id);
# 			$(template).addClass("newAlert")
# 			$(template).attr("callOnHide", true);
# 			$("#callAlertLimbo").append($(template));
#
# 			id = "#" + id;
#
# 			message = "<p>".concat(message.concat("</p><br/><br/>"));
# 			$(id).find(".modal-message").html(message);
#
# 			var str_title = "Aviso";
# 			if (title !== undefined && title != null && title.trim() != "")
# 				str_title = title;
# 			$(id).find(".modal-title").html(str_title);
#
# 			if (str_title == "&nbsp;")
# 				$(id).remove(".modal-title");
#
# 			var str_okText = "Entendi";
# 			if (okText !== undefined && okText != null && okText.trim() != "")
# 				str_okText = okText;
# 			$(id).find(".modal-petz-btn.ok").html(str_okText);
#
# 			if(showCancel === undefined || showCancel == null)
# 				showCancel = false;
#
# 			if(showCancel) {
# 				$(id).find(".modal-petz-btn.cancel").css("display", "block");
#
# 				var str_cancelText = "Cancelar";
# 				if (cancelText !== undefined && cancelText != null && cancelText.trim() != "")
# 					str_cancelText = cancelText;
# 				$(id).find(".modal-petz-btn.cancel").html(str_cancelText);
# 			}
#
# 			$(id).find(".modal-petz-btn.ok").click(function() {
# 				if (callback !== undefined && callback != null) {
# 					callback(callbackParams);
# 					$(template).attr("callOnHide", false);
# 				}
# 				$(id).modal("hide");
# 			});
#
# 			$(id).find(".modal-petz-btn.cancel").click(function() {
# 				if (callbackCancel !== undefined && callbackCancel != null) {
# 					callbackCancel(callbackCancelParams);
# 					$(template).attr("callHide", false);
# 				}
# 				$(id).modal("hide");
# 			});
#
# 			if (cssClass !== undefined && cssClass != null) {
#                 $(id).addClass(cssClass);
#             } else if( /Android|webOS|iPhone|iPad|iPod|BlackBerry|IEMobile|Opera Mini/i.test(navigator.userAgent) ) {
#                 $(id).addClass("newAlert");
#             } else {
#                 $(id).addClass("novoPopup");
# 			}
#
#
# 			$(id).modal("show");
#
# 			//Caso seja clicado fora do modal, executa a funÃ§Ã£o
# 			$(id).on('hidden.bs.modal', function(){
# 				if (callbackHide !== undefined && callbackHide != null && $(template).attr("callOnHide") == "true") {
# 					callbackHide(callbackHideParams);
# 				}
# 				$(id).modal("hide");
# 			});
# 		}
#
# 	</script>
# <style>
# 		.escondido {
# 			display: none;
# 		}
# 		.modal .modal-header{
# 		    padding: 15px !important;
# 		}
# 		.modal-header {
# 		    border: 0;
# 		}
# 		.modal-body{
# 		    text-align: center;
# 		    width: 100%;
# 		}
# 		.modal-message small{
# 			font-size: 14px;
# 		}
# 		.processing{margin-bottom: 20px; width:32%}
# 		.modal-message strong{
# 			top: 20px;
#   			color: #17479E;
#   			font-size: 18px;
#   		}
#   		.popupEntregaExpressa .modal-message p span {
#             font-weight: bold;
#             color: #17479E;
#         }
# 		.popupEntregaExpressa .modal-message{text-align: left;}
# 		@media screen and (max-width: 767px){
# 			.modal-dialog{
# 				margin: 65px auto;
# 			    width: 85vw;
# 			    height: auto;
# 			}
# 			.modal-message {font-size: 16px;}
# 			.modal-petz-btn.cancel{margin-top: 0px;}
# 			.btns{
# 				display: flex;
# 				justify-content: center;
# 				align-items: center;
# 			}
# 			.btns a {margin: 0 10px;}
# 			.btns a + a{margin-left: 0px}
# 			.exclusao-popup .btns a{width: 48%;}
# 			.exclusao-popup .modal-content .btns .btn {
# 				width: 50%;
# 			}
# 			.exclusao-popup .modal-content .btns .modal-petz-btn.ok {
# 				border-radius: 7px;
# 				background-color: white;
# 				color: #35A836;
# 				border: 2px solid #35A836;
# 			}
# 			.delete-btns a:only-child{width: 100%;}
# 			.exclusao-popup .modal-body{padding-bottom: 15px;}
# 			.exclusao-popup .modal-message{padding-bottom: 20px; margin: 0px;font-size: 16px;}
# 			.exclusao-popup .modal-header{padding-bottom: 5px;}
#
# 			/*Novo Alert*/
# 			.newAlert.callAlertModal{margin: 0}
# 			.newAlert.callAlertModal.popupEntregaExpressa{background-color:#FFF;}
#             .newAlert.callAlertModal .modal-content{width: 100vw !important}
#             .newAlert .modal-dialog {
#                 margin: 0;
#                 width: 100vw !important;
#                 height: 100%;
#             }
#             .newAlert .modal-dialog .modal-content{
#                 height: 100%;
#                 display: flex;
#                 flex-direction: column;
#                 justify-content: space-between;
#                 border: none;
# 				border-radius: 0;
#             }
# 						.newAlert.callAlertModal.popupEntregaExpressa .modal-dialog .modal-content .modal-body {
# 							padding: 10px 15px;
# 						}
#             .newAlert .modal-dialog .modal-content .modal-header {flex: 0.1}
#             .newAlert .modal-dialog .modal-content .modal-body {flex: 3}
#             .newAlert .modal-dialog .modal-content .btns {flex: 0.5; padding: 8px 15px;}
#
#             .newAlert .modal-dialog .modal-content .modal-body {
#                 overflow: auto;
#             }
#             .newAlert .modal-dialog .modal-content .modal-header{
#                 display: flex;
#                 align-items: center;
#                 justify-content: space-between;
#                 position: relative;
#                 background-color: #ffd400;
#                 padding: 20px 20px;
#             }
#             .newAlert .modal-dialog .modal-content .modal-header:after,
#             .newAlert .modal-dialog .modal-content .modal-header:before {
#                 content: initial;
#             }
#             .newAlert .petz_modal_header .close{position: absolute; margin:0}
#             .newAlert .petz_modal_header button.close{
#                 font-size: 35px;
#                 font-weight: 400;
#                 color: #1B6DB0;
#                 opacity: 1;
#                 text-shadow: none;
#                 position: initial;
# 								background-color: transparent;
# 								border: none;
#             }
#
#             .newAlert .modal-title{
#                 color: #1B6DB0;
#                 font-size: 20px;
#                 font-weight: bold;
#                 text-transform: initial;
#             }
#             .newAlert .modal-message{
#                 text-align: left;
#             }
# 			.modal-petz-btn {
# 			    border-radius: 7px;
# 					height: 54px;
# 					line-height: 32px;
# 			    padding: 15px;
# 			    background-color: white;
# 			    color: #35A836;
# 			    box-shadow: none;
# 			    border: 2px solid #35A836;
# 			    text-transform: initial;
# 			    width: 80%;
# 			    margin-left: auto;
# 			    margin-right: auto;
# 			}
# 			.btn-enter-mobile {
# 			    font-size: 18px;
# 			    font-weight: bold;
#                 height: 54px;
#                 box-shadow: none;
#                 width: 80%;
#                 margin-left: auto;
#                 margin-right: auto;
#                 margin-top: 10px;
#                 margin-bottom: 15px;
# 			}
# 			.modal-petz-btn.cancel {
# 			    background: white;
# 			    color: #4d4d4d;
# 			    border-color: #4d4d4d;
# 			    box-shadow: none;
# 			}
# 		}
#
# 	    .popupBannerAssinaturaProduto .modal-title {
#             font-size: 24px;
#             color: #17479E;
#         }
#         .popupBannerAssinaturaProduto img {
#             width: 100%;
#
#         }
#         .popupBannerAssinaturaProduto .modal-body {
#             padding: 0;
#         }
#         .popupBannerAssinaturaProduto .modal-message,
#         .popupBannerAssinaturaProduto .modal-message p {
#             height: 100%;
#         }
# 		.throbber .modal-content {
# 			border-radius: 6px;
# 		}
# 	</style>
# </head>
# <div id="callAlertLimbo">
# </div>
# <div class="escondido" id="divThrobberCallAlert">
# <div>
# <img alt="Aguarde..." class="processing" loading="lazy" src="https://www.petz.com.br/novaLoja/images/loading.gif" title="Aguarde...">
# <br/><strong><b>Carregando...</b></strong>
# </img></div>
# </div>
# <!-- POPUP DESK -->
# <div class="escondido" id="callAlertTemplate">
# <div class="modal fade callAlertModal" id="callAlertTemplatePopup" role="dialog">
# <div class="modal-dialog">
# <div class="modal-content">
# <div class="modal-header petz_modal_header">
# <button aria-hidden="true" class="close" data-dismiss="modal" type="button">×</button>
# <div class="modal-title">Mensagem</div>
# </div>
# <div class="modal-body petz-modal">
# <div class="social-icons-conatainer">
# <div class="modal-body">
# <p class="modal-message"></p>
# <div class="btns">
# <button class="btn modal-petz-btn ok" type="button">OK</button>
# <button class="btn modal-petz-btn cancel escondido" type="button">Cancelar</button>
# </div>
# </div>
# </div>
# <div class="clearfix"></div>
# </div>
# <div class="clearfix"></div>
# </div>
# </div>
# </div>
# </div>
# <script>
#     /* funcoes para setar e obter cookies */
#     function pegaCookie(e){var t=document.cookie,n=t.indexOf(e+"="),o=n+e.length+1;if(!n&&e!=t.substring(0,e.length))return null;if(-1==n)return null;var l=t.indexOf(";",o);return-1==l&&(l=t.length),t.substring(o,l)}function setCookie(e,t,n){if(n){var o=new Date;o.setTime(o.getTime()+24*n*60*60*1e3);var l="; expires="+o.toGMTString()}else l="";return document.cookie=e+"="+t+l+("localhost"!=dominioWeb?"; domain=."+dominioWeb:"")+"; path=/",!0}
#     function guardaCookie(e,t,n){if(n){var o=new Date;o.setTime(o.getTime()+24*n*60*60*1e3);var l="; expires="+o.toGMTString()}else l="";return document.cookie=e+"="+t+l+("localhost"!=dominioWeb?"; domain=."+dominioWeb:"")+"; path=/",!0}
# </script>
# <script type="text/javascript">
# 		document.addEventListener("DOMContentLoaded", function(event) {
# 		    if(pegaCookie('utm_medium') != null && pegaCookie('utm_medium') != "") {
#                 let params = {"idCamp":"89", "utm_medium":pegaCookie('utm_medium')};
#                 jQuery.ajax({
#                     url: ctx + "/aplicarCupom_Loja.html",
#                     data: params,
#                     async: false,
#                     success: function(data){
#                         if (data.sucesso) {
#                             guardaCookie('utm_medium', '', 0);
#                         }
#                     }
#                  });
#             }
# 		});
# 		</script>
# <script type="text/javascript">
# 		document.addEventListener("DOMContentLoaded", function(event) {
# 		    if(pegaCookie('utm_medium') != null && pegaCookie('utm_medium') != "") {
#                 let params = {"idCamp":"90", "utm_medium":pegaCookie('utm_medium')};
#                 jQuery.ajax({
#                     url: ctx + "/aplicarCupom_Loja.html",
#                     data: params,
#                     async: false,
#                     success: function(data){
#                         if (data.sucesso) {
#                             guardaCookie('utm_medium', '', 0);
#                         }
#                     }
#                  });
#             }
# 		});
# 		</script>
# <script type="text/javascript">
# ...
# <div class="flex spacebet">
# <ul>
# <li><a href="/">Pet Shop</a></li>
# <li><a href="/colecao/advocate">Advocate</a></li>
# <li><a href="/gato/racoes-e-alimentos/f/royal-canin">Royal Canin Gatos</a></li>
# <li><a href="/golden">Ração Golden</a></li>
# <li><a href="/produto/glicopan">Glicopan Pet</a></li>
# <li><a href="/cachorro/casinha-de-cachorro/casas">Casinha de Cachorro</a></li>
# </ul>
# <ul>
# <li><a href="/cachorro/racoes-e-alimentos/racoes-secas">Ração para Cachorro</a></li>
# <li><a href="/gato/brinquedos/arranhador-para-gatos">Arranhador para Gatos</a></li>
# <li><a href="/peixes/aquarios-e-beteiras/aquarios-completos">Aquários</a></li>
# <li><a href="/cachorro/cama-de-cachorro">Cama para Cachorro</a></li>
# <li><a href="/frontline">Frontline</a></li>
# <li><a href="/royalcanin">Royal Canin</a></li>
# </ul>
# <ul>
# <li><a href="/bayer">Bayer Pet</a></li>
# <li><a href="/pedigree">Pedigree</a></li>
# <li><a href="/premier">Ração Premier</a></li>
# <li><a href="/produto/baytril">Baytril</a></li>
# <li><a href="/colecao/advantage-max3">Advantage Max 3</a></li>
# <li><a href="/seresto">Seresto</a></li>
# </ul>
# <ul>
# <li><a href="/frontline-plus">Frontline Plus</a></li>
# <li><a href="/nexgard">Nexgard</a></li>
# <li><a href="/cachorro/passeio-e-viagem/coleiras-guias-e-peitorais">Coleira</a></li>
# <li><a href="/whiskas">Whiskas</a></li>
# <li><a href="/produto/capstar">Capstar</a></li>
# <li><a href="/colecao/hamster">Hamster</a></li>
# </ul>
# <ul>
# <li><a href="/colecao/gaiola">Gaiola</a></li>
# <li><a href="/produto/gaiola-monaco-para-calopsita-triplex-80479">Gaiola para calopsita</a></li>
# <li><a href="/gato/brinquedos">Brinquedos para gatos</a></li>
# <li><a href="/cachorro/higiene-e-beleza/maquinas-de-tosa-e-acessorios">Máquina de tosa para cachorros</a></li>
# <li><a href="/colecao/drontal">Drontal</a></li>
# <li><a href="/colecao/royal-canin-filhotes">Royal Canin Filhotes</a></li>
# </ul>
# <ul>
# <li><a href="/hills">Ração Hills</a></li>
# <li><a href="/cachorro/casinha-de-cachorro/portoes-e-extensores">Portão para cachorro</a></li>
# <li><a href="/proplan">Proplan</a></li>
# <li><a href="/gato/brinquedos/brinquedos-com-erva-de-gatos">Erva do gato</a></li>
# </ul>
# </div>
# <div class="border-top border-bottom" id="footerAlphabeticList">
# <div class="flex center">
# <b>Glossário de Marcas:</b>
# <span><a href="/marcas/a">A</a></span>
# <span><a href="/marcas/b">B</a></span>
# <span><a href="/marcas/c">C</a></span>
# <span><a href="/marcas/d">D</a></span>
# <span><a href="/marcas/e">E</a></span>
# <span><a href="/marcas/f">F</a></span>
# <span><a href="/marcas/g">G</a></span>
# <span><a href="/marcas/h">H</a></span>
# <span><a href="/marcas/i">I</a></span>
# <span><a href="/marcas/j">J</a></span>
# <span><a href="/marcas/k">K</a></span>
# <span><a href="/marcas/l">L</a></span>
# <span><a href="/marcas/m">M</a></span>
# <span><a href="/marcas/n">N</a></span>
# <span><a href="/marcas/o">O</a></span>
# <span><a href="/marcas/p">P</a></span>
# <span><a href="/marcas/q">Q</a></span>
# <span><a href="/marcas/r">R</a></span>
# <span><a href="/marcas/s">S</a></span>
# <span><a href="/marcas/t">T</a></span>
# <span><a href="/marcas/u">U</a></span>
# <span><a href="/marcas/v">V</a></span>
# <span><a href="/marcas/w">W</a></span>
# <span><a href="/marcas/x">X</a></span>
# <span><a href="/marcas/y">Y</a></span>
# <span><a href="/marcas/z">Z</a></span>
# </div>
# </div>
# </div>
# </section>
# <section id="footerCopyright">
# <div class="container" itemprop="address" itemscope="" itemtype="http://schema.org/PostalAddress">
# <p class="tx-center">Pet Center Comércio Participações S/A - CNPJ 18.328.118/0013-42 -
#             <span itemprop="streetAddress">Endereço: Rua Dr. Miguel Paulo Capalbo, 135</span> - Pari -
#             <span itemprop="addressLocality">São Paulo</span> - <span itemprop="addressRegion">SP</span> - CEP: <span itemprop="postalCode">03035-040</span>
# <br/>Copyright© 2021 Pet Center Comércio e Participações S/A - Todos os direitos reservados
#         </p>
# </div>
# </section>
# </div>
# </footer>
# <link href="https://fonts.googleapis.com/css2?family=Roboto:wght@300;400;500;700;900&amp;display=swap" rel="stylesheet"/>
# </div>
# <a class="back-to-top" href="#" id="backToTopButton">
# <span class="visuallyhidden">Voltar para o topo da página</span>
# <i aria-hidden="true" class="fa fa-angle-up"></i>
# </a>
# <div id="NeoassistCentral"></div>
#
# <div class="policy-warning-banner ">
# <span class="policy-text">Utilizamos cookies para garantir que você tenha a melhor experiência. Ao continuar no site, você estará de acordo com a nossa <a href="/institucional/politica-de-privacidade" target="_blank">Política de Privacidade.</a></span>
# <button class="policy-button" id="aceiteLgpd" onclick="policyAccept()">OK</button>
# </div>
# <script type="text/javascript">
#       function policyAccept(){
#         let acceptanceDate = new Date();
#
#         document.cookie = "aceiteData=" + acceptanceDate.toISOString() + ";max-age=604800;path=/";
#
#
#
#           document.cookie = "aceiteUsuario=;max-age=604800;path=/";
#
#
#         $(".policy-warning-banner").css("display", "none");
#       }
#     </script>
# <link as="style" href="https://maxcdn.bootstrapcdn.com/font-awesome/4.6.1/css/font-awesome.min.css" rel="preload">
# <link href="https://maxcdn.bootstrapcdn.com/font-awesome/4.6.1/css/font-awesome.min.css" rel="stylesheet">
# <!-- 	   		<script async defer src="//static.chaordicsystems.com/static/loader.js" data-apikey="petz" type="text/javascript"></script> -->
# <!-- Global site tag (gtag.js) - Google Analytics -->
# <script defer="" src="https://www.googletagmanager.com/gtag/js?id=UA-58792402-1"></script>
# <script>
#         window.dataLayer = window.dataLayer || [];
#         function gtag(){dataLayer.push(arguments);}
#         gtag('js', new Date());
#
#         gtag('config', 'UA-58792402-1', { 'optimize_id': 'GTM-KGPPHRL', 'send_page_view': false });
#     </script>
# <script type="text/javascript">
# 		var urlParameters;
# 		(window.onpopstate = function () {
# 		    var match,
# 		        pl     = /\+/g,  // Regex for replacing addition symbol with a space
# 		        search = /([^&=]+)=?([^&]*)/g,
# 		        decode = function (s) { return unescape(s.replace(pl, " ")); },
# 		        query  = window.location.search.substring(1);
#
# 		    urlParameters = {};
# 		    while (match = search.exec(query))
# 		    	urlParameters[decode(match[1])] = decode(match[2]);
# 		})();
#
# 		// this code will run after all other $(document).ready() scripts
# 		// have completely finished, AND all page elements are fully loaded.
# 		jQuery(document).ready(function() {
# 			jQuery(window).load(function() {
# 				freeScroll = true;
# 		    });
# 		});
# 	</script>
# <script defer="" src="https://www13.directtalk.com.br/clientes/custom/Petz/widget.min.js"></script>
# <script type="text/javascript">
#             $(".promoblackfriday").addClass("promo");
#             $(".promo").removeClass("promoblackfriday");
#             $("#promocoes_link").removeClass("blackfriday");
#
# 	            $("#promocoes_titulo").text("Promoções");
# 	            $("#promocoes_titulo").parent()[0].href = "https://www.petz.com.br/promocoes";
#
#
#         </script>
# <script type="text/javascript">
# 			+function (a, p, P, b, y) {
# 				a.appboy = {}; a.appboyQueue = []; for (var s = "initialize destroy getDeviceId toggleAppboyLogging setLogger openSession changeUser requestImmediateDataFlush requestFeedRefresh subscribeToFeedUpdates requestContentCardsRefresh subscribeToContentCardsUpdates logCardImpressions logCardClick logCardDismissal logFeedDisplayed logContentCardsDisplayed logInAppMessageImpression logInAppMessageClick logInAppMessageButtonClick logInAppMessageHtmlClick subscribeToNewInAppMessages subscribeToInAppMessage removeSubscription removeAllSubscriptions logCustomEvent logPurchase isPushSupported isPushBlocked isPushGranted isPushPermissionGranted registerAppboyPushMessages unregisterAppboyPushMessages trackLocation stopWebTracking resumeWebTracking wipeData ab ab.DeviceProperties ab.User ab.User.Genders ab.User.NotificationSubscriptionTypes ab.User.prototype.getUserId ab.User.prototype.setFirstName ab.User.prototype.setLastName ab.User.prototype.setEmail ab.User.prototype.setGender ab.User.prototype.setDateOfBirth ab.User.prototype.setCountry ab.User.prototype.setHomeCity ab.User.prototype.setLanguage ab.User.prototype.setEmailNotificationSubscriptionType ab.User.prototype.setPushNotificationSubscriptionType ab.User.prototype.setPhoneNumber ab.User.prototype.setAvatarImageUrl ab.User.prototype.setLastKnownLocation ab.User.prototype.setUserAttribute ab.User.prototype.setCustomUserAttribute ab.User.prototype.addToCustomAttributeArray ab.User.prototype.removeFromCustomAttributeArray ab.User.prototype.incrementCustomUserAttribute ab.User.prototype.addAlias ab.User.prototype.setCustomLocationAttribute ab.InAppMessage ab.InAppMessage.SlideFrom ab.InAppMessage.ClickAction ab.InAppMessage.DismissType ab.InAppMessage.OpenTarget ab.InAppMessage.ImageStyle ab.InAppMessage.TextAlignment ab.InAppMessage.Orientation ab.InAppMessage.CropType ab.InAppMessage.prototype.subscribeToClickedEvent ab.InAppMessage.prototype.subscribeToDismissedEvent ab.InAppMessage.prototype.removeSubscription ab.InAppMessage.prototype.removeAllSubscriptions ab.InAppMessage.prototype.closeMessage ab.InAppMessage.Button ab.InAppMessage.Button.prototype.subscribeToClickedEvent ab.InAppMessage.Button.prototype.removeSubscription ab.InAppMessage.Button.prototype.removeAllSubscriptions ab.SlideUpMessage ab.ModalMessage ab.FullScreenMessage ab.HtmlMessage ab.ControlMessage ab.Feed ab.Feed.prototype.getUnreadCardCount ab.ContentCards ab.ContentCards.prototype.getUnviewedCardCount ab.Card ab.Card.prototype.subscribeToClickedEvent ab.Card.prototype.subscribeToDismissedEvent ab.Card.prototype.removeSubscription ab.Card.prototype.removeAllSubscriptions ab.Card.prototype.dismissCard ab.ClassicCard ab.CaptionedImage ab.Banner ab.ControlCard ab.WindowUtils display display.automaticallyShowNewInAppMessages display.showInAppMessage display.showFeed display.destroyFeed display.toggleFeed display.showContentCards display.hideContentCards display.toggleContentCards sharedLib".split(" "), i = 0; i < s.length; i++) { for (var m = s[i], k = a.appboy, l = m.split("."), j = 0; j < l.length - 1; j++)k = k[l[j]]; k[l[j]] = (new Function("return function " + m.replace(/\./g, "_") + "(){window.appboyQueue.push(arguments); return true}"))() } window.appboy.getUser = function () { return new window.appboy.ab.User }; window.appboy.getCachedFeed = function () { return new window.appboy.ab.Feed }; window.appboy.getCachedContentCards = function () { return new window.appboy.ab.ContentCards }; (y = p.createElement(P)).type = 'text/javascript';
# 				y.src = 'https://js.appboycdn.com/web-sdk/2.7/appboy.min.js';
# 				y.async = 1; (b = p.getElementsByTagName(P)[0]).parentNode.insertBefore(y, b)
# 			}(window, document, 'script');
#
# 			appboy.initialize('36fe242-c969-42d6-8504-62feab34deda', {
# 				manageServiceWorkerExternally: true
# 			});
# 			appboy.display.automaticallyShowNewInAppMessages();
#
#
# 			appboy.openSession();
# 		</script>
# <!-- Google Tag Manager -->
# <script type="text/javascript">
# 			var usarSegment = false;
# 				if(usarSegment){
# 				setTimeout(function() {
# 					(function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({'gtm.start':
# 								new Date().getTime(),event:'gtm.js'});var f=d.getElementsByTagName(s)[0],
# 							j=d.createElement(s),dl=l!='dataLayer'?'&l='+l:'';j.async=true;j.src=
# 							'//www.googletagmanager.com/gtm.js?id='+i+dl;f.parentNode.insertBefore(j,f);
# 					})(window,document,'script','dataLayer','GTM-M3LQVBK');
# 					console.log("gtm_exec");
# 				}, 3000);
# 			}
# 		</script>
# <!-- End Google Tag Manager -->
# <script type="text/javascript">
# 		var ctx = '';
# 		var ctxFotos = 'https://staticpetz.stoom.com.br';
# 	</script>
# <script type="text/javascript">
# 			var BLACKFRIDAY = false;
# 		</script>
# <!-- Script que aciona o tracker caso tenha retornado do cadastro de um novo cliente -->
# <script type="text/javascript">
#
# 		/* defaultLojaPadrao.jsp / defaultLojaMobile.jsp / checkoutPrincipal.jsp / assinaturaToten.jsp */
#
# 		function gaEvent(categoria, acao, rotulo, valor) {
# 			var log = "gaEvent: " + categoria + "/" + acao + "/" + rotulo + "/" + valor;
# 			try {
# 				if (ga !== undefined)
# 					ga('send', 'event', categoria, acao, rotulo/*, valor*/);
#
# 				if (ajaxSysout !== undefined)
# 					ajaxSysout(log);
#
# 				console.log(log);
# 			}
# 			catch(ex) {
# 				log += " / erro #" + ex.message;
# 				if (ajaxSysout !== undefined)
# 					ajaxSysout(log);
# 				console.log(log);
# 			}
# 		}
# 	</script>
# <script type="text/javascript">
# 		document.addEventListener("DOMContentLoaded", function(event) {
# 			jQuery(function(){
# 				jQuery("#search").autocomplete({
# 					serviceUrl: 'https://subservices.petz.com.br/buscaAutoComplete_Loja.html',
# 					onSelect: function (suggestion) {
# 				     //  alert('You selected: ' + suggestion.value + ', ' + suggestion.data);
# 				     	jQuery("#search").parents("form").submit();
# 						sendAnalyticsSearchClicked("Search Recommendation");
# 					}
# 				});
# 			});
# 		});
# 	</script>
# <script type="text/javascript">
# 			if(typeof pageTypeDefault === "undefined"){
# 					pageTypeDefault = "";
# 			}
# 			var str = window.location.pathname;
# 			str = str.split("/");
# 			var pageName = str[str.length - 1];
# 			if(pageName === ""){
# 					pageName = "Home"
# 			}
# 			var usarSegment = true;
# 			if(usarSegment){
# 					!function(){var analytics=window.analytics=window.analytics||[];if(!analytics.initialize)if(analytics.invoked)window.console&&console.error&&console.error("Segment snippet included twice.");else{analytics.invoked=!0;analytics.methods=["trackSubmit","trackClick","trackLink","trackForm","pageview","identify","reset","group","track","ready","alias","debug","page","once","off","on"];
# 					analytics.factory=function(t){return function(){var e=Array.prototype.slice.call(arguments);e.unshift(t);
# 					analytics.push(e);return
# 					analytics}};for(var t=0;t<analytics.methods.length;t++){var e=analytics.methods[t];analytics[e]=analytics.factory(e)}analytics.load=function(t,e){var n=document.createElement("script");n.type="text/javascript";n.async=!0;n.src="https://cdn.segment.com/analytics.js/v1/"+t+"/analytics.min.js";var a=document.getElementsByTagName("script")[0];a.parentNode.insertBefore(n,a);
# 					analytics._loadOptions=e};
# 					analytics.SNIPPET_VERSION="4.1.0";
# 					analytics.load("x7a5ftBXuhYuVkSO32T4PTWpZRv0EESp");
# 					analytics.ready(function() {
# 						window.analytics.page(pageName,{type: pageTypeDefault});
# 					});
# 					}}();
# 			}
# 	</script>
# <script type="text/javascript">
# 		document.addEventListener("DOMContentLoaded", function(event) {
# 		var usarSegment = true;
# 						if(usarSegment){
# 					var hasAnonymousId = false;
#
# 								if (!hasAnonymousId) {
# 										var segmentAnonymousId = analytics.user().anonymousId();
# 										jQuery.ajax({
# 											type: 'POST',
# 											url: ctx + "/setSegmentAnonymousId_Loja.html?segmentAnonymousId="+segmentAnonymousId,
# 											success: function(response) { return true; }
# 										});
# 								}
# 						}
# 		});
# 	</script>
# <script>
# 		window.onload = function() {
# 			if(window.location !== window.parent.location) {
# 				$("#bot").remove();
# 				$("#backToTopButton").remove();
# 			}
#
# 			console.clear();
# 		};
# 	</script>
# <script defer="" src="https://www.petz.com.br/novaLoja/scripts/script.js" type="text/javascript"></script>
# <script>
# 		// Based on https://www.filamentgroup.com/lab/async-css.html
# 		var fontMaterialIcon = document.createElement( "link" );
# 		fontMaterialIcon.rel = "stylesheet";
# 		fontMaterialIcon.href = "https://fonts.googleapis.com/icon?family=Material+Icons&display=swap";
# 		document.head.insertBefore( fontMaterialIcon, document.head.childNodes[ document.head.childNodes.length - 1 ].nextSibling );
# 	</script>
# <script defer="" src="https://www.petz.com.br/novaLoja/scripts/apiv3/apiCaller.js" type="text/javascript"></script>
# <script defer="" src="https://www.petz.com.br/novaLoja/scripts/apiv3/cart.js" type="text/javascript"></script>
# </link></link>

# %%
lista = ['primeiro', 'segundo', 'terceiro', 'quinto']
for index, item in enumerate(lista, start=10):
  print(f"{index} - {item}")
# Out:
# 10 - primeiro
# 11 - segundo
# 12 - terceiro
# 13 - quinto

# %%
import re
stores = []
for index, store in enumerate(soup.find_all("div", {"class": "store"}), start=1):
    name = store.find("h2", {"itemprop": "name"}).get_text().strip()
    address = store.find("p", {"itemprop": "address"})
    address = address.get_text()
    address = re.sub(' +', ' ', address)
    address = " ".join([s for s in address.strip().splitlines(False) if s.strip()])
    addressLoc = store.find("span", {"itemprop": "addressLocality"}).get_text().strip()
    region = store.find("span", {"itemprop": "addressRegion"}).get_text().strip()
    telephone = store.find("p", {"itemprop": "telephone"}).get_text().strip()
    openingHours = store.find("p", {"itemprop": "openingHours"}).get_text().strip()  
    row = {	'name': name, 			'address':address, 
		'telephone': telephone, 		'openingHours':openingHours, 
		'addressLocality': addressLoc, 	'region': region}    
    stores.append(row) 
stores
# Out:
# [{'address': 'Av. Gov. Agamenon Magalhães, 3855 Santo Amaro - Recife/PE CEP: 50050-290',
#   'addressLocality': 'Recife',
#   'name': 'Petz Agamenon',
#   'openingHours': 'Segunda a domingo - das 08:00 às 22:00\n Feriado - das 09:00 às 18:00',
#   'region': 'PE',
#   'telephone': '(81) 3033-7590'},
#  {'address': 'Av. Alphaville, 580 Alphaville - Barueri/SP CEP: 06472-010',
#   'addressLocality': 'Barueri',
#   'name': 'Petz Alphaville',
#   'openingHours': 'Todos os dias - das 09:00 às 22:00',
#   'region': 'SP',
#   'telephone': '(11) 2181-7355'},
#  {'address': 'Av. Adolfo Pinheiro, 1600 Santo Amaro - São Paulo/SP CEP: 04734-004',
#   'addressLocality': 'São Paulo',
#   'name': 'Petz Alto da Boa Vista',
#   'openingHours': 'Todos os dias - das 09:00 às 22:00',
#   'region': 'SP',
#   'telephone': '(11) 2181-7330'},
#  {'address': 'Av. Paulista, 985 Vila Nossa Sra. de Fatima - Americana/SP CEP: 13478-580',
#   'addressLocality': 'Americana',
#   'name': 'Petz Americana',
#   'openingHours': 'Todos os dias - das 09:00 às 22:00',
#   'region': 'SP',
#   'telephone': '(19) 3468-7913'},
#  {'address': 'Avenida Ana Costa, 215 Gonzaga - Santos/SP CEP: 11060-001',
#   'addressLocality': 'Santos',
#   'name': 'Petz Ana Costa',
#   'openingHours': 'Segunda a sábado - das 09:00 às 22:00\n Domingo e Feriado - das 08:00 às 22:00',
#   'region': 'SP',
#   'telephone': '(13) 3202-7400'},
#  {'address': 'Av. Regente Feijó, 677 Vila Regente Feijó - São Paulo/SP CEP: 03342-000',
#   'addressLocality': 'São Paulo',
#   'name': 'Petz Anália Franco',
#   'openingHours': 'Todos os dias - das 09:00 às 22:00',
#   'region': 'SP',
#   'telephone': '(11) 2181-7360'},
#  {'address': 'Av. Angélica, 2011 Higienópolis - São Paulo/SP CEP: 01227-200',
#   'addressLocality': 'São Paulo',
#   'name': 'Petz Angélica',
#   'openingHours': 'Todos os dias - das 09:00 às 22:00',
#   'region': 'SP',
#   'telephone': '(11) 2181-7342'},
#  {'address': 'Av. Prof. Luiz Ignacio Anhaia Mello, 5657  - Junto ao Roldão Vila Graciosa - São Paulo/SP CEP: 03295-000',
#   'addressLocality': 'São Paulo',
#   'name': 'Petz Anhaia Mello',
#   'openingHours': 'Todos os dias - das 09:00 às 22:00',
#   'region': 'SP',
#   'telephone': '(11) 2181-7470'},
#  {'address': 'Av. Ministro Geraldo Barreto Sobral, 140 Jardins - Aracaju/SE CEP: 49026-900',
#   'addressLocality': 'Aracaju',
#   'name': 'Petz Aracaju',
#   'openingHours': 'Segunda a domingo - das 08:00 às 22:00\n Feriado - das 12:00 às 18:00',
#   'region': 'SE',
#   'telephone': '(79) 3045-4858'},
#  {'address': 'Av. Brasília, 2737 Vila Sao Paulo - Araçatuba/SP CEP: 16018-000',
#   'addressLocality': 'Araçatuba',
#   'name': 'Petz Araçatuba',
#   'openingHours': 'Todos os dias - das 09:00 às 22:00',
#   'region': 'SP',
#   'telephone': '(18) 3117-6771'},
#  {'address': 'Av.Rio das Pedras, 2207  - Junto a Telha Norte Jardim Aricanduva - São Paulo/SP CEP: 03453-100',
#   'addressLocality': 'São Paulo',
#   'name': 'Petz Aricanduva',
#   'openingHours': 'Todos os dias - das 09:00 às 22:00',
#   'region': 'SP',
#   'telephone': '(11) 2181-7308'},
#  {'address': 'Rua Augusta , 215 Bela Vista - São Paulo/SP CEP: 01305-000',
#   'addressLocality': 'São Paulo',
#   'name': 'Petz Augusta',
#   'openingHours': 'Todos os dias - das 09:00 às 00:00',
#   'region': 'SP',
#   'telephone': '(11) 2181-7365'},
#  {'address': 'Av. Ayrton Senna, 3437  - Junto a Etna Barra da Tijuca - Rio de Janeiro/RJ CEP: 22775-005',
#   'addressLocality': 'Rio de Janeiro',
#   'name': 'Petz Ayrton Senna',
#   'openingHours': 'Segunda a sábado - das 08:00 às 22:00\n Domingo e Feriado - das 10:00 às 21:00',
#   'region': 'RJ',
#   'telephone': '(21) 3161-7389'},
#  {'address': 'Av. do Estado, 4888 Estados - Balneário Camboriú/SC CEP: 88339-060',
#   'addressLocality': 'Balneário Camboriú',
#   'name': 'Petz Balneário Camboriú',
#   'openingHours': 'Todos os dias - das 09:00 às 22:00',
#   'region': 'SC',
#   'telephone': '(47) 3311-7760\n                                        \n                                            / (47) 3311-7758'},
#  {'address': 'Av. dos Bandeirantes, 2040 Vila Olímpia - São Paulo/SP CEP: 04553-902',
#   'addressLocality': 'São Paulo',
#   'name': 'Petz Bandeirantes',
#   'openingHours': 'Todos os dias - 24h',
#   'region': 'SP',
#   'telephone': '(11) 2181-7305'},
#  {'address': 'Avenida das Américas, 6571  - Lote 02 Pal 45164 Barra da Tijuca - Rio de Janeiro/RJ CEP: 22631-004',
#   'addressLocality': 'Rio de Janeiro',
#   'name': 'Petz Barra Américas',
#   'openingHours': 'Todos os dias - das 08:00 às 22:00',
#   'region': 'RJ',
#   'telephone': '(21) 3161-7389'},
#  {'address': 'RUA RUBENS PAGANI , 444 Jardim Estoril - São Paulo/SP CEP: 17016-210',
#   'addressLocality': 'São Paulo',
#   'name': 'Petz Bauru',
#   'openingHours': 'Todos os dias - das 09:00 às 22:00',
#   'region': 'SP',
#   'telephone': '(14) 3204-7389'},
#  {'address': 'Av. Juiz Marco Tulio Isaac, 470 Parque das Industrias - Betim/MG CEP: 32671-072',
#   'addressLocality': 'Betim',
#   'name': 'Petz Betim',
#   'openingHours': 'Todos os dias - das 08:00 às 22:00',
#   'region': 'MG',
#   'telephone': '(31) 3079-7389'},
#  {'address': 'R. São Paulo, 1629 Itoupava Seca - Blumenau/SC CEP: 89030-001',
#   'addressLocality': 'Blumenau',
#   'name': 'Petz Blumenau',
#   'openingHours': 'Todos os dias - das 09:00 às 22:00',
#   'region': 'SC',
#   'telephone': '(47) 3036-5490'},
#  {'address': 'Rua Professor João Medeiros, 139 Boa Viagem - Recife/PE CEP: 51020-000',
#   'addressLocality': 'Recife',
#   'name': 'Petz Boa Viagem',
#   'openingHours': 'Segunda a sábado - das 08:00 às 00:00\n Domingo e Feriado - das 09:00 às 18:00',
#   'region': 'PE',
#   'telephone': '(81) 3033-7590'},
#  {'address': 'Av. Paulo Faccini, 1385  Macedo - Guarulhos/SP CEP: 07111-000',
#   'addressLocality': 'Guarulhos',
#   'name': 'Petz Bosque Ma',
#   'openingHours': 'Todos os dias - das 09:00 às 23:00',
#   'region': 'SP',
#   'telephone': '(11) 2181-7465'},
#  {'address': 'Rua General Polidoro, 113 Botafogo - Rio de Janeiro/RJ CEP: 22280-004',
#   'addressLocality': 'Rio de Janeiro',
#   'name': 'Petz Botafogo',
#   'openingHours': 'Todos os dias - das 08:00 às 22:00',
#   'region': 'RJ',
#   'telephone': '(21) 3161-7390'},
#  {'address': 'SIA trecho 02, Lotes 65/95 , 65/95 Guará I - Brasília/DF CEP: 71200-207',
#   'addressLocality': 'Brasília',
#   'name': 'Petz Brasília',
#   'openingHours': 'Segunda a sábado - das 08:00 às 22:00\n Domingo e Feriado - das 08:00 às 21:00',
#   'region': 'DF',
#   'telephone': '(61) 3221-7389'},
#  {'address': 'ST STN, Conjunto D, BLOCO 2/B, S/N  - TERMINAL NORTE CONJ D BLOCO2/B Asa Norte - Brasília/DF CEP: 70770-100',
#   'addressLocality': 'Brasília',
#   'name': 'Petz Brasília Asa Norte',
#   'openingHours': 'Todos os dias - das 08:00 às 23:00',
#   'region': 'DF',
#   'telephone': '(61) 3221-7389'},
#  {'address': 'Epia Sul, , Lote 3 Candangolândia - Brasília/DF CEP: 71738-010',
#   'addressLocality': 'Brasília',
#   'name': 'Petz Brasília Epia',
#   'openingHours': 'Todos os dias - das 08:00 às 22:00',
#   'region': 'DF',
#   'telephone': '(61) 3221-7389'},
#  {'address': 'Av. Das Paineiras - Q. 1 Lote E , S/N  - Próximo a Paróquia Santa Clara Jardim Botânico - Brasília/DF CEP: 70297-400',
#   'addressLocality': 'Brasília',
#   'name': 'Petz Brasília Jardim Botânico',
#   'openingHours': 'Todos os dias - das 08:00 às 22:00',
#   'region': 'DF',
#   'telephone': '(61) 3221-7389'},
#  {'address': 'Av T63, S/N  - Quadra 143 lote 4/13  Setor Bueno - Goiânia/GO CEP: 74230-105',
#   'addressLocality': 'Goiânia',
#   'name': 'Petz Bueno T63',
#   'openingHours': 'Todos os dias - das 08:00 às 00:00',
#   'region': 'GO',
#   'telephone': '(62) 2764-7389'},
#  {'address': 'Av. Professor Francisco Morato, 1796  - 1798 Butantã - São Paulo/SP CEP: 05512-200',
#   'addressLocality': 'São Paulo',
#   'name': 'Petz Butantã',
#   'openingHours': 'Todos os dias - das 09:00 às 22:00',
#   'region': 'SP',
#   'telephone': '(11) 2181-7340'},
#  {'address': 'Av. Doutor Moraes Sales, 2326 Nova Campinas - Campinas/SP CEP: 13100-201',
#   'addressLocality': 'Campinas',
#   'name': 'Petz Cambuí',
#   'openingHours': 'Todos os dias - das 09:00 às 22:00',
#   'region': 'SP',
#   'telephone': '(19) 3341-7389'},
#  {'address': 'Av. Afonso Pena, 5420 Chacara Cachoeira - Campo Grande/MS CEP: 79040-010',
#   'addressLocality': 'Campo Grande',
#   'name': 'Petz Campo Grande',
#   'openingHours': 'Segunda a domingo - das 08:00 às 22:00\n Feriado - das 09:00 às 18:00',
#   'region': 'MS',
#   'telephone': '(67) 3222-6097'},
#  {'address': 'Avenida Getúlio Vargas, 6401 Marechal Rondon - Canoas/RS CEP: 92020-020',
#   'addressLocality': 'Canoas',
#   'name': 'Petz Canoas',
#   'openingHours': 'Segunda a domingo - das 09:00 às 22:00\n Feriado - das 09:00 às 18:00',
#   'region': 'RS',
#   'telephone': '(51) 3052-0478'},
#  {'address': 'Rua Vereador Antônio Cruz Arouca, 200 Indaiá - Caraguatatuba/SP CEP: 11665-100',
#   'addressLocality': 'Caraguatatuba',
#   'name': 'Petz Caraguatatuba',
#   'openingHours': 'Todos os dias - das 09:00 às 22:00',
#   'region': 'SP',
#   'telephone': '(12) 3886-6040'},
#  {'address': 'Avenida Inocêncio Seráfico, 3375 Vila Silva Ribeiro - Carapicuíba/SP CEP: 06380-021',
#   'addressLocality': 'Carapicuíba',
#   'name': 'Petz Carapicuíba',
#   'openingHours': 'Todos os dias - das 09:00 às 22:00',
#   'region': 'SP',
#   'telephone': '(11) 2181-7328'},
#  {'address': 'Avenida Presidente Carlos Luz, 710 Caiçaras - Belo Horizonte/MG CEP: 31230-010',
#   'addressLocality': 'Belo Horizonte',
#   'name': 'Petz Carlos Luz',
#   'openingHours': 'Todos os dias - das 08:00 às 22:00',
#   'region': 'MG',
#   'telephone': '(31) 3079-7389'},
#  {'address': 'Av .Marginal Direita Anchieta, 3398 Jardim Maria Estela - São Paulo/SP CEP: 04246-900',
#   'addressLocality': 'São Paulo',
#   'name': 'Petz Carrefour Anchieta',
#   'openingHours': 'Todos os dias - das 09:00 às 22:00',
#   'region': 'SP',
#   'telephone': '(11) 2181-7317'},
#  {'address': 'R. Ribeiro Lacerda, 940  - Estacionamento G3 Carrefour Bosque da Saúde - São Paulo/SP CEP: 04147-020',
#   'addressLocality': 'São Paulo',
#   'name': 'Petz Carrefour Imigrantes',
#   'openingHours': 'Todos os dias - das 09:00 às 21:00',
#   'region': 'SP',
#   'telephone': '(11) 2181-7320'},
#  {'address': 'R. Oliveira Botelho, 349  - Dentro do Carrefour Manilha Neves - São Gonçalo/RJ CEP: 24426-270',
#   'addressLocality': 'São Gonçalo',
#   'name': 'Petz Carrefour Manilha',
#   'openingHours': 'Segunda a sábado - das 08:00 às 22:00\n Domingo - das 08:00 às 21:00\n Feriado - das 08:00 às 22:00',
#   'region': 'RJ',
#   'telephone': '(21) 3161-7389'},
#  {'address': 'Av Coronel Fernando Ferreira Leite, 1540  - Ribeirão Shopping Jardim Califórnia - Ribeirão Preto/SP CEP: 14026-020',
#   'addressLocality': 'Ribeirão Preto',
#   'name': 'Petz Carrefour Ribeirão Shopping',
#   'openingHours': 'Todos os dias - das 09:00 às 22:00',
#   'region': 'SP',
#   'telephone': '(16) 3602-8190'},
#  {'address': 'Avenida do Estado, 1750  - junto ao Carrefour Fundação - São Caetano do Sul/SP CEP: 09550-400',
#   'addressLocality': 'São Caetano do Sul',
#   'name': 'Petz Carrefour São Caetano',
#   'openingHours': 'Todos os dias - das 09:00 às 21:00',
#   'region': 'SP',
#   'telephone': '(11) 2181-7425'},
#  {'address': 'Avenida Brasil, 4254 Centro - Cascavel/PR CEP: 85812-000',
#   'addressLocality': 'Cascavel',
#   'name': 'Petz Cascavel',
#   'openingHours': 'Todos os dias - das 09:00 às 22:00',
#   'region': 'PR',
#   'telephone': '(45) 3035-8060'},
#  {'address': 'Rod. Mabio Gonçalves Palhano, 195  - em frente ao Catuaí Shopping Gleba Fazenda Palhano - Londrina/PR CEP: 86055-585',
#   'addressLocality': 'Londrina',
#   'name': 'Petz Catuai Londrina',
#   'openingHours': 'Todos os dias - das 09:00 às 22:00',
#   'region': 'PR',
#   'telephone': '(43) 3032-1060'},
#  {'address': 'Av. Eduardo Prado, 415 Cavalhada - Porto Alegre/RS CEP: 91751-000',
#   'addressLocality': 'Porto Alegre',
#   'name': 'Petz Cavalhada',
#   'openingHours': 'Todos os dias - das 09:00 às 22:00',
#   'region': 'RS',
#   'telephone': '(51) 3557-4779'},
#  {'address': 'Av Rubens Bento Alves, 8457 Cinquentenário - Caxias do Sul/RS CEP: 95012-393',
#   'addressLocality': 'Caxias do Sul',
#   'name': 'Petz Caxias do Sul',
#   'openingHours': 'Todos os dias - das 09:00 às 22:00',
#   'region': 'RS',
#   'telephone': '(54) 3538-2760'},
#  {'address': 'Av. Pastor Anselmo Silvestre, 1395 , 1495  - Shopping Center Minas Dom Joaquim - Belo Horizonte/MG CEP: 31170678',
#   'addressLocality': 'Belo Horizonte',
#   'name': 'Petz Center Minas',
#   'openingHours': 'Segunda a sábado - das 08:00 às 22:00\n Domingo e Feriado - das 08:00 às 20:00',
#   'region': 'MG',
#   'telephone': '(31) 3079-7389'},
#  {'address': 'Shopping Center Norte - Tv. Casalbuono, 120  - Alameda de Serviços Vila Guilherme - São Paulo/SP CEP: 02029-010',
#   'addressLocality': 'São Paulo',
#   'name': 'Petz Center Norte',
#   'openingHours': 'Segunda a sábado - das 09:00 às 22:00\n Domingo e Feriado - das 09:00 às 21:00',
#   'region': 'SP',
#   'telephone': '(11) 2181-7445'},
#  {'address': 'Av. Pacaembu, 1140 Pacaembu - São Paulo/SP CEP: 01234-000',
#   'addressLocality': 'São Paulo',
#   'name': 'Petz Centro Veterinário 24h',
#   'openingHours': 'Todos os dias - 24h',
#   'region': 'SP',
#   'telephone': '(11) 2181-7480\n                                        \n                                            / (11) 2609-2519'},
#  {'address': 'Rua Cerro Corá, 1950 Vila Romana - São Paulo/SP CEP: 05061-300',
#   'addressLocality': 'São Paulo',
#   'name': 'Petz Cerro Corá',
#   'openingHours': 'Todos os dias - das 09:00 às 00:00',
#   'region': 'SP',
#   'telephone': '(11) 2181-7321'},
#  {'address': 'Av dos Tajuras, 147  - 161 Cidade Jardim - São Paulo/SP CEP: 05670-000',
#   'addressLocality': 'São Paulo',
#   'name': 'Petz Cidade Jardim',
#   'openingHours': 'Todos os dias - das 09:00 às 22:00',
#   'region': 'SP',
#   'telephone': '(11) 21817345'},
#  {'address': 'Av. Moreira Guimarães, 631   - 657 Indianópolis - São Paulo/SP CEP: 04074-030',
#   'addressLocality': 'São Paulo',
#   'name': 'Petz Congonhas',
#   'openingHours': 'Todos os dias - das 09:00 às 00:00',
#   'region': 'SP',
#   'telephone': '(11) 2181-7303'},
#  {'address': 'Av. Babita Camargos, 1295  - Loja 03 Cidade Industrial - Contagem/MG CEP: 32210-180',
#   'addressLocality': 'Contagem',
#   'name': 'Petz Contagem',
#   'openingHours': 'Todos os dias - das 08:00 às 22:00',
#   'region': 'MG',
#   'telephone': '(31) 3079-7389'},
#  {'address': 'R. Martinho Boschetti, 2083 Picadas do Sul - São José/SC CEP: 88106-110',
#   'addressLocality': 'São José',
#   'name': 'Petz Continente',
#   'openingHours': 'Todos os dias - das 09:00 às 22:00',
#   'region': 'SC',
#   'telephone': '(48) 3181-0700'},
#  {'address': 'Av. Nossa Senhora de Copacabana, 1246 Copacabana - Rio de Janeiro/RJ CEP: 22070-012',
#   'addressLocality': 'Rio de Janeiro',
#   'name': 'Petz Copacabana',
#   'openingHours': 'Todos os dias - das 08:00 às 21:00',
#   'region': 'RJ',
#   'telephone': '(21) 3161-7389'},
#  {'address': 'Rodovia Raposo Tavares KM 21, 5650  - Acesso também pela Rua Damasco Lageadinho - Cotia/SP CEP: 06709-015',
#   'addressLocality': 'Cotia',
#   'name': 'Petz Cotia',
#   'openingHours': 'Todos os dias - das 09:00 às 00:00',
#   'region': 'SP',
#   'telephone': '(11) 2181-7323'},
#  {'address': 'Avenida Diário de Notícias, 1500 Cristal - Porto Alegre/RS CEP: 90810-080',
#   'addressLocality': 'Porto Alegre',
#   'name': 'Petz Diário de Notícias',
#   'openingHours': 'Todos os dias - das 09:00 às 22:00',
#   'region': 'RS',
#   'telephone': '(51) 3557-4779'},
#  {'address': 'Av. Djalma Batista, 3000 Chapada - Manaus/AM CEP: 69050-010',
#   'addressLocality': 'Manaus',
#   'name': 'Petz Djalma Batista',
#   'openingHours': 'Todos os dias - das 08:00 às 22:00',
#   'region': 'AM',
#   'telephone': '(92) 3024-6531'},
#  {'address': 'Av. Guilherme Campos, 500  - Shopping Parque Dom Pedro  Centro (Pq Dom Pedro Shopping) - Campinas/SP CEP: 13087-901',
#   'addressLocality': 'Campinas',
#   'name': 'Petz Dom Pedro',
#   'openingHours': 'Segunda a sábado - das 09:00 às 22:00\n Domingo e Feriado - das 10:00 às 20:00',
#   'region': 'SP',
#   'telephone': '(19) 3341-7389'},
#  {'address': 'Av. Dom Pedro I, S/N  - LOTE 1 E 2 ENSEADA - Guarujá/SP CEP: 11440-110',
#   'addressLocality': 'Guarujá',
#   'name': 'Petz Enseada',
#   'openingHours': 'Todos os dias - das 09:00 às 22:00',
#   'region': 'SP',
#   'telephone': '(13) 3202-7401'},
#  {'address': 'Av. Jorge Zarur, 100 Jardim Apolo - São José dos Campos/SP CEP: 12243-081',
#   'addressLocality': 'São José dos Campos',
#   'name': 'Petz Extra Colinas',
#   'openingHours': 'Todos os dias - das 09:00 às 22:00',
#   'region': 'SP',
#   'telephone': '(12) 3904-4300'},
#  {'address': 'Rua José Higino, 115  - Dentro do Extra Maracanã Maracanã - Rio de Janeiro/RJ CEP: 20520-201',
#   'addressLocality': 'Rio de Janeiro',
#   'name': 'Petz Extra Maracanã',
#   'openingHours': 'Segunda a sábado - das 08:00 às 23:00\n Domingo e Feriado - das 08:00 às 22:00',
#   'region': 'RJ',
#   'telephone': '(21) 3161-7389'},
#  {'address': 'Avenida Fernando Corrêa da Costa, 1682 Pico do Amor - Cuiabá/MT CEP: 78065-000',
#   'addressLocality': 'Cuiabá',
#   'name': 'Petz Fernando Corrêa',
#   'openingHours': 'Todos os dias - das 08:00 às 22:00',
#   'region': 'MT',
#   'telephone': '(65) 3025-8889'},
#  {'address': 'Rodovia José Carlos Daux, 5500  - Square SC Corporate Saco Grande - Florianópolis/SC CEP: 88032-005',
#   'addressLocality': 'Florianópolis',
#   'name': 'Petz Florianópolis',
#   'openingHours': 'Todos os dias - das 09:00 às 22:00',
#   'region': 'SC',
#   'telephone': '(48) 3181-0700'},
#  {'address': 'Av. Paraná, 1314 Região Central - Foz do Iguaçu/PR CEP: 85863-754',
#   'addressLocality': 'Foz do Iguaçu',
#   'name': 'Petz Foz do Iguaçu',
#   'openingHours': 'Todos os dias - das 09:00 às 22:00',
#   'region': 'PR',
#   'telephone': '(45) 3026-3800'},
#  {'address': 'Av. Dr. Ismael Alonso Y Alonso, 450 Jardim Veneza - Franca/SP CEP: 14400-190',
#   'addressLocality': 'Franca',
#   'name': 'Petz Franca',
#   'openingHours': 'Todos os dias - das 09:00 às 22:00',
#   'region': 'SP',
#   'telephone': '(16) 3602-8192'},
#  {'address': 'Rua Giovanni Battista Pirelli, 1645 Vila Homero Thon - Santo André/SP CEP: 09111-340',
#   'addressLocality': 'Santo André',
#   'name': 'Petz Giovanni Pirelli',
#   'openingHours': 'Todos os dias - das 09:00 às 22:00',
#   'region': 'SP',
#   'telephone': '(11) 2181-7455'},
#  {'address': 'Av. Adhemar de Barros, 1935 Jardim Helena Maria - Guarujá/SP CEP: 11430-003',
#   'addressLocality': 'Guarujá',
#   'name': 'Petz Guarujá',
#   'openingHours': 'Todos os dias - das 09:00 às 22:00',
#   'region': 'SP',
#   'telephone': '(13) 3202 7400'},
#  {'address': 'Av. Guarulhos, 2598 Ponte Grande - Guarulhos/SP CEP: 07022-020',
#   'addressLocality': 'Guarulhos',
#   'name': 'Petz Guarulhos',
#   'openingHours': 'Todos os dias - das 09:00 às 23:00',
#   'region': 'SP',
#   'telephone': '(11) 2181-7415'},
#  {'address': 'Estr. Juscelino Kubtischek de Oliv., 4380 Jardim Albertina - Guarulhos/SP CEP: 07252-000',
#   'addressLocality': 'Guarulhos',
#   'name': 'Petz Guarulhos Pimentas',
#   'openingHours': 'Todos os dias - das 09:00 às 22:00',
#   'region': 'SP',
#   'telephone': '(11) 2181-7324'},
#  {'address': 'Av. Gisele Constantino, 1850  - Shopping Iguatemi Esplanada Parque Bela Vista - Votorantim/SP CEP: 18110-650',
#   'addressLocality': 'Votorantim',
#   'name': 'Petz Iguatemi Esplanada',
#   'openingHours': 'Segunda a sábado - das 10:00 às 22:00\n Domingo e Feriado - das 12:00 às 20:00',
#   'region': 'SP',
#   'telephone': '(15) 3247-5535\n                                        \n                                            / (15) 3331-8400'},
#  {'address': 'Estrada do Galeão, 1770 Jardim Carioca - Rio de Janeiro/RJ CEP: 21931-524',
#   'addressLocality': 'Rio de Janeiro',
#   'name': 'Petz Ilha do Governador',
#   'openingHours': 'Todos os dias - das 08:00 às 22:00',
#   'region': 'RJ',
#   'telephone': '(21) 3161-7392'},
#  {'address': 'Alameda Filtros Mann, 670   - Polo Shopping Indaiatuba  Jardim Tropical - Indaiatuba/SP CEP: 13344-580',
#   'addressLocality': 'Indaiatuba',
#   'name': 'Petz Indaiatuba',
#   'openingHours': 'Segunda a sábado - das 10:00 às 22:00\n Domingo e Feriado - das 12:00 às 20:00',
#   'region': 'SP',
#   'telephone': '(19) 3341-7389'},
#  {'address': 'Av. Presidente Tancredo Neves, 600 Ipiranga - São Paulo/SP CEP: 04287-010',
#   'addressLocality': 'São Paulo',
#   'name': 'Petz Ipiranga',
#   'openingHours': 'Segunda a sábado - das 09:00 às 21:00\n Domingo e Feriado - das 09:00 às 20:00',
#   'region': 'SP',
#   'telephone': '(11) 2181-7315'},
#  {'address': 'R. Bandeira Paulista, 982 Itaim Bibi - São Paulo/SP CEP: 04532-003',
#   'addressLocality': 'São Paulo',
#   'name': 'Petz Itaim',
#   'openingHours': 'Todos os dias - das 09:00 às 00:00',
#   'region': 'SP',
#   'telephone': '(11) 2181-7375'},
#  {'address': 'Avenida Marechal Castelo Branco, 55 Jardim de Lucca - Itatiba/SP CEP: 13255-350',
#   'addressLocality': 'Itatiba',
#   'name': 'Petz Itatiba',
#   'openingHours': 'Todos os dias - das 09:00 às 22:00',
#   'region': 'SP',
#   'telephone': '(11) 4487-6550'},
#  {'address': 'Av. Dr. Otaviano Pereira Mendes, 1254 Liberdade - Itu/SP CEP: 13301-000',
#   'addressLocality': 'Itu',
#   'name': 'Petz Itu',
#   'openingHours': 'Segunda a domingo - das 09:00 às 22:00\n Feriado - das 09:00 às 20:00',
#   'region': 'SP',
#   'telephone': '(11) 21817314'},
#  {'address': 'Av. Ayrton Senna da Silva, 1485 Piedade - Jaboatão dos Guararapes/PE CEP: 54420-700',
#   'addressLocality': 'Jaboatão dos Guararapes',
#   'name': 'Petz Jaboatão dos Guararapes',
#   'openingHours': 'Todos os dias - das 08:00 às 22:00',
#   'region': 'PE',
#   'telephone': '(81) 3033-7590'},
#  {'address': 'Av Jacu Pêssego , 4710 Itaquera - São Paulo/SP CEP: 08215115',
#   'addressLocality': 'São Paulo',
#   'name': 'Petz Jacu Pêssego',
#   'openingHours': 'Todos os dias - das 09:00 às 23:00',
#   'region': 'SP',
#   'telephone': '(11) 2181-7450'},
#  {'address': 'Avenida Corifeu de Azevedo Marques, 4529  - lado ímpar da Corifeu Vila Lageado - São Paulo/SP CEP: 05339003',
#   'addressLocality': 'São Paulo',
#   'name': 'Petz Jaguaré',
#   'openingHours': 'Todos os dias - das 09:00 às 23:00',
#   'region': 'SP',
#   'telephone': '(11) 2181-7350'},
#  {'address': 'R. Jardim Botânico, 733 Lagoa - Rio de Janeiro/RJ CEP: 22470-051',
#   'addressLocality': 'Rio de Janeiro',
#   'name': 'Petz Jardim Botânico',
#   'openingHours': 'Todos os dias - das 09:00 às 22:00',
#   'region': 'RJ',
#   'telephone': '(21) 3161-7394'},
#  {'address': 'R. Dr. Paulo César, 249 Santa Rosa - Niterói/RJ CEP: 24240-000',
#   'addressLocality': 'Niterói',
#   'name': 'Petz Jardim Icaraí',
#   'openingHours': 'Todos os dias - das 09:00 às 22:00',
#   'region': 'RJ',
#   'telephone': '(21) 3161-7393'},
#  {'address': 'Avenida Doutor Quinzinho , 51 Chácara Peccioli - Jaú/SP CEP: 17210-110',
#   'addressLocality': 'Jaú',
#   'name': 'Petz Jaú',
#   'openingHours': 'Segunda a sábado - das 09:00 às 22:00\n Domingo - das 09:00 às 20:00\n Feriado - das 09:00 às 17:00',
#   'region': 'SP',
#   'telephone': '(14) 3225-1704'},
#  {'address': 'Av. João Firmino, 342 Assunção - São Bernardo do Campo/SP CEP: 09810-250',
#   'addressLocality': 'São Bernardo do Campo',
#   'name': 'Petz João Firmino',
#   'openingHours': 'Todos os dias - das 09:00 às 22:00',
#   'region': 'SP',
#   'telephone': '(11) 2181-7337'},
#  {'address': 'R. Dr. João Colin, 940 América - Joinville/SC CEP: 89204-070',
#   'addressLocality': 'Joinville',
#   'name': 'Petz Joinville',
#   'openingHours': 'Segunda a sábado - das 09:00 às 22:00\n Domingo e Feriado - das 12:00 às 20:00',
#   'region': 'SC',
#   'telephone': '(47) 3207-3386'},
#  {'address': 'Avenida Rio Branco, 3820 Alto dos Passos - Juiz de Fora/MG CEP: 36026-500',
#   'addressLocality': 'Juiz de Fora',
#   'name': 'Petz Juiz de Fora',
#   'openingHours': 'Segunda a domingo - das 08:00 às 22:00\n Feriado - loja fechada',
#   'region': 'MG',
#   'telephone': '(32) 3321-8582'},
#  {'address': 'Av. Antonio Frederico Ozanan, 3003  - Junto ao Atacadista Roldão Vila de Vito - Jundiaí/SP CEP: 13215-010',
#   'addressLocality': 'Jundiaí',
#   'name': 'Petz Jundiaí',
#   'openingHours': 'Segunda a sábado - das 09:00 às 22:00\n Domingo e Feriado - das 09:00 às 20:00',
#   'region': 'SP',
#   'telephone': '(11) 2181-7440'},
#  {'address': 'Avenida Direitos Humanos, 1436 Lauzane Paulista - São Paulo/SP CEP: 02475-001',
#   'addressLocality': 'São Paulo',
#   'name': 'Petz Lauzane Paulista',
#   'openingHours': 'Todos os dias - das 09:00 às 22:00',
#   'region': 'SP',
#   'telephone': '(11) 2181-7326'},
#  {'address': 'Av. Otaviano Alves de Lima, 1480 Limão - São Paulo/SP CEP: 02901-000',
#   'addressLocality': 'São Paulo',
#   'name': 'Petz Limão',
#   'openingHours': 'Todos os dias - das 09:00 às 23:00',
#   'region': 'SP',
#   'telephone': '(11) 3855-4400\n                                        \n                                            / (11) 2181-7325'},
#  {'address': 'Av. Ayrton Senna da Silva, 1511  - Litoral Plaza Shopping Tude Bastos - Praia Grande/SP CEP: 11726-000',
#   'addressLocality': 'Praia Grande',
#   'name': 'Petz Litoral Plaza',
#   'openingHours': 'Segunda a sábado - das 09:00 às 22:00\n Domingo - das 10:00 às 22:00\n Feriado - das 10:00 às 21:00',
#   'region': 'SP',
#   'telephone': '(13) 3202-7400'},
#  {'address': 'Rua Manuel Gaya, 2000 Vila Mazzei - São Paulo/SP CEP: 02313-000',
#   'addressLocality': 'São Paulo',
#   'name': 'Petz Manuel Gaya',
#   'openingHours': 'Todos os dias - das 09:00 às 22:00',
#   'region': 'SP',
#   'telephone': '(11) 2181-7300'},
#  {'address': 'Avenida Marechal Tito, 5699  - Junto a Center Castilho Itaim Paulista - São Paulo/SP CEP: 08115-100',
#   'addressLocality': 'São Paulo',
#   'name': 'Petz Marechal Tito',
#   'openingHours': 'Todos os dias - das 09:00 às 22:00',
#   'region': 'SP',
#   'telephone': '(11) 2181-7307'},
#  {'address': 'Av. Presidente Castelo Branco, 1795 Pari - São Paulo/SP CEP: 03035-050',
#   'addressLocality': 'São Paulo',
#   'name': 'Petz Marginal Tietê 24h',
#   'openingHours': 'Todos os dias - 24h',
#   'region': 'SP',
#   'telephone': '(11) 2181-7380'},
#  {'address': 'Av. Paraná, 1250 Zona 7 - Maringá/PR CEP: 87020-085',
#   'addressLocality': 'Maringá',
#   'name': 'Petz Maringá',
#   'openingHours': 'Segunda a sábado - das 09:00 às 22:00\n Domingo e Feriado - loja fechada',
#   'region': 'PR',
#   'telephone': '(44) 3123-2350'},
#  {'address': 'Rua Mateus Leme, 1875 Bom Retiro - Curitiba/PR CEP: 80520-174',
#   'addressLocality': 'Curitiba',
#   'name': 'Petz Mateus Leme',
#   'openingHours': 'Todos os dias - das 09:00 às 22:00',
#   'region': 'PR',
#   'telephone': '(41) 3528-7389'},
#  {'address': 'Av. Miguel Sutil , 10000 Jardim Mariana - Cuiabá/MT CEP: 78040-790',
#   'addressLocality': 'Cuiabá',
#   'name': 'Petz Miguel Sutil',
#   'openingHours': 'Todos os dias - das 08:00 às 22:00',
#   'region': 'MT',
#   'telephone': '(65) 3025-8889'},
#  {'address': 'Av. Francisco Rodrigues Filho, 1550 Botujuru - Mogi das Cruzes/SP CEP: 08840-000',
#   'addressLocality': 'Mogi das Cruzes',
#   'name': 'Petz Mogi das Cruzes',
#   'openingHours': 'Todos os dias - das 09:00 às 21:00',
#   'region': 'SP',
#   'telephone': '(11) 2181-7435'},
#  {'address': 'Rua Quintino Bocaiúva, 433 Floresta - Porto Alegre/RS CEP: 90440-051',
#   'addressLocality': 'Porto Alegre',
#   'name': 'Petz Moinhos de Vento',
#   'openingHours': 'Todos os dias - das 09:00 às 22:00',
#   'region': 'RS',
#   'telephone': '(51) 3557-4779'},
#  {'address': 'Av. Paes de Barros, 1654 Mooca - São Paulo/SP CEP: 03114-001',
#   'addressLocality': 'São Paulo',
#   'name': 'Petz Mooca',
#   'openingHours': 'Todos os dias - das 09:00 às 22:00',
#   'region': 'SP',
#   'telephone': '(11) 2181-7400'},
#  {'address': 'Rua Aureliano Guimarães, 201 Morumbi - São Paulo/SP CEP: 05727-160',
#   'addressLocality': 'São Paulo',
#   'name': 'Petz Morumbi',
#   'openingHours': 'Todos os dias - das 09:00 às 22:00',
#   'region': 'SP',
#   'telephone': '(11) 2181-7389'},
#  {'address': 'Avenida das Nações Unidas, 20727 Vila Almeida - São Paulo/SP CEP: 04795-100',
#   'addressLocality': 'São Paulo',
#   'name': 'Petz Nações Unidas',
#   'openingHours': 'Todos os dias - das 09:00 às 22:00',
#   'region': 'SP',
#   'telephone': '(11) 2181-7318'},
#  {'address': 'Av. Sen. Salgado Filho, 2431 Lagoa Nova - Natal/RN CEP: 59075-000',
#   'addressLocality': 'Natal',
#   'name': 'Petz Natal',
#   'openingHours': 'Todos os dias - das 08:00 às 00:00',
#   'region': 'RN',
#   'telephone': '(84) 3301-6517'},
#  {'address': 'Av. Dr. João Medeiros Filho, 1420 Potengi - Natal/RN CEP: 59108-550',
#   'addressLocality': 'Natal',
#   'name': 'Petz Natal Zona Norte',
#   'openingHours': 'Todos os dias - das 08:00 às 22:00',
#   'region': 'RN',
#   'telephone': '(84) 3301-6517'},
#  {'address': 'Av. Nordestina, 2740 Cidade Nova São Miguel - São Paulo/SP CEP: 08042-117',
#   'addressLocality': 'São Paulo',
#   'name': 'Petz Nordestina',
#   'openingHours': 'Todos os dias - das 09:00 às 22:00',
#   'region': 'SP',
#   'telephone': '(11) 2181-7332'},
#  {'address': 'Av. Nossa Senhora do Carmo, 1448 São Pedro - Belo Horizonte/MG CEP: 30330-000',
#   'addressLocality': 'Belo Horizonte',
#   'name': 'Petz Nossa Senhora do Carmo',
#   'openingHours': 'Todos os dias - das 08:00 às 00:00',
#   'region': 'MG',
#   'telephone': '(31) 3079-7389'},
#  {'address': 'Rua Castro Alves, 205 Rio Branco - Novo Hamburgo/RS CEP: 93310-270',
#   'addressLocality': 'Novo Hamburgo',
#   'name': 'Petz Novo Hamburgo',
#   'openingHours': 'Todos os dias - das 09:00 às 22:00',
#   'region': 'RS',
#   'telephone': '(51) 3273-9229'},
#  {'address': 'Av. dos Autonomistas, 1473  - Parte A  Vila Yara - Osasco/SP CEP: 06090-010',
#   'addressLocality': 'Osasco',
#   'name': 'Petz Osasco',
#   'openingHours': 'Todos os dias - das 09:00 às 00:00',
#   'region': 'SP',
#   'telephone': '(11) 2181-7304'},
#  {'address': 'Praça Charles Miller, 117 Pacaembu - São Paulo/SP CEP: 01234-010',
#   'addressLocality': 'São Paulo',
#   'name': 'Petz Pacaembu',
#   'openingHours': 'Todos os dias - das 09:00 às 00:00',
#   'region': 'SP',
#   'telephone': '(11) 2181-7460'},
#  {'address': 'Q. 101 Sul Avenida LO 3, S/N Plano Diretor Sul - Palmas/TO CEP: 77015-002',
#   'addressLocality': 'Palmas',
#   'name': 'Petz Palmas',
#   'openingHours': 'Segunda a sexta - das 08:00 às 20:00\n Sábado, Domingo e Feriado - das 09:00 às 20:00',
#   'region': 'TO',
#   'telephone': '(63) 3025-1432'},
#  {'address': 'Av. Professor Magalhães Penido, 1000 Liberdade - Belo Horizonte/MG CEP: 31270-652',
#   'addressLocality': 'Belo Horizonte',
#   'name': 'Petz Pampulha',
#   'openingHours': 'Todos os dias - das 08:00 às 22:00',
#   'region': 'MG',
#   'telephone': '(31) 3079-7389'},
#  {'address': 'Av. Deputado Jamel Cecílio, s/n  - quadra B16, lotes 17/19 Jardim Goiás - Goiânia/GO CEP: 74810-100',
#   'addressLocality': 'Goiânia',
#   'name': 'Petz Parque Flamboyant',
#   'openingHours': 'Todos os dias - das 08:00 às 22:00',
#   'region': 'GO',
#   'telephone': '(62) 2764-7389'},
#  {'address': 'Avenida Santos Dumont, 4360 Centro - Lauro de Freitas/BA CEP: 42702-400',
#   'addressLocality': 'Lauro de Freitas',
#   'name': 'Petz Parque Shopping Bahia',
#   'openingHours': 'Segunda a sábado - das 08:00 às 22:00\n Domingo e Feriado - das 13:00 às 21:00',
#   'region': 'BA',
#   'telephone': '(71) 3506-1390'},
#  {'address': 'Av. Perimetral Norte, 8303  - Fazenda das Caveiras Passeio das Águas - Goiânia/GO CEP: 74445-360',
#   'addressLocality': 'Goiânia',
#   'name': 'Petz Passeio das Águas',
#   'openingHours': 'Segunda a sábado - das 10:00 às 22:00\n Domingo e Feriado - das 14:00 às 20:00',
#   'region': 'GO',
#   'telephone': '(62) 2764-7389'},
#  {'address': 'Avenida Ferreira Viana, 1511 Areal - Pelotas/RS CEP: 96085-000',
#   'addressLocality': 'Pelotas',
#   'name': 'Petz Pelotas',
#   'openingHours': 'Todos os dias - das 09:00 às 22:00',
#   'region': 'RS',
#   'telephone': '(53) 3026-1819'},
#  {'address': 'Rua Thales Dos Santos Freire, 36  - Quadra 8B LOT 26,27,28,29 e 30 Baeta Neves - São Bernardo do Campo/SP CEP: 09751-020',
#   'addressLocality': 'São Bernardo do Campo',
#   'name': 'Petz Pereira Barreto',
#   'openingHours': 'Todos os dias - das 09:00 às 22:00',
#   'region': 'SP',
#   'telephone': '(11) 2181-7475'},
#  {'address': 'Av. Centenário, 780 São Dimas - Piracicaba/SP CEP: 13416-000',
#   'addressLocality': 'Piracicaba',
#   'name': 'Petz Piracicaba',
#   'openingHours': 'Todos os dias - das 09:00 às 22:00',
#   'region': 'SP',
#   'telephone': '(19) 3341-7389'},
#  {'address': 'Av. José Munia, 4775  - Shopping Plaza Avenida, Piso T Redentor - São José do Rio Preto/SP CEP: 15085-350',
#   'addressLocality': 'São José do Rio Preto',
#   'name': 'Petz Plaza Avenida Shopping',
#   'openingHours': 'Segunda a sábado - das 10:00 às 22:00\n Domingo e Feriado - das 14:00 às 20:00',
#   'region': 'SP',
#   'telephone': '(17) 3301-2797'},
#  {'address': 'Av. João Pinheiro, 711 Centro - Poços de Caldas/MG CEP: 37701-387',
#   'addressLocality': 'Poços de Caldas',
#   'name': 'Petz Poços de Caldas',
#   'openingHours': 'Todos os dias - das 09:00 às 22:00',
#   'region': 'MG',
#   'telephone': '(35) 3014-9100'},
#  {'address': 'Av. Francisco Matarazzo, 2000  - Complexo SP MEGA STORES Água Branca - São Paulo/SP CEP: 05001-200',
#   'addressLocality': 'São Paulo',
#   'name': 'Petz Pompeia',
#   'openingHours': 'Todos os dias - das 09:00 às 22:00',
#   'region': 'SP',
#   'telephone': '(11) 2181-7405'},
#  {'address': 'Av. Presidente Kennedy, 2900 Guilhermina - Praia Grande/SP CEP: 11600-000',
#   'addressLocality': 'Praia Grande',
#   'name': 'Petz Praia Grande',
#   'openingHours': 'Segunda a sexta - das 09:00 às 22:00\n Sábado, Domingo e Feriado - das 08:00 às 22:00',
#   'region': 'SP',
#   'telephone': '(13) 3202-7402'},
#  {'address': 'Av. Manoel Goulart, 2671 Centro Educacional - Presidente Prudente/SP CEP: 19010-000',
#   'addressLocality': 'Presidente Prudente',
#   'name': 'Petz Presidente Prudente',
#   'openingHours': 'Segunda a domingo - das 09:00 às 22:00\n Feriado - das 09:00 às 20:00',
#   'region': 'SP',
#   'telephone': '(18) 3904-5500'},
#  {'address': 'Av. Protásio Alves, 4194  - Loja 2 Petrópolis - Porto Alegre/RS CEP: 91310-000',
#   'addressLocality': 'Porto Alegre',
#   'name': 'Petz Protásio Alves',
#   'openingHours': 'Segunda-feira - das 08:00 às 00:00\n Terça-feira - das 09:00 às 00:00\n Quarta-feira - das 09:00 às 00:00\n Quinta-feira - das 09:00 às 00:00\n Sexta-feira - das 09:00 às 00:00\n Sábado - das 09:00 às 00:00\n Domingo - das 09:00 às 00:00\n Feriado - das 09:00 às 00:00',
#   'region': 'RS',
#   'telephone': '(51) 3557-4779'},
#  {'address': 'Av. Alcântara Machado , 3300 bras - São Paulo/SP CEP: 03102-007',
#   'addressLocality': 'São Paulo',
#   'name': 'Petz Radial Leste',
#   'openingHours': 'Todos os dias - das 09:00 às 00:00',
#   'region': 'SP',
#   'telephone': '(11) 2181-7430'},
#  {'address': 'Avenida Raja Gabaglia, 3230 Estoril Belo Horizonte - Belo Horizonte/MG CEP: 30360-670',
#   'addressLocality': 'Belo Horizonte',
#   'name': 'Petz Raja Gabaglia',
#   'openingHours': 'Todos os dias - das 08:00 às 22:00',
#   'region': 'MG',
#   'telephone': '(31) 3079-7389'},
#  {'address': 'Avenida Independência , 1810 Jardim Sumare - Ribeirão Preto/SP CEP: 14025-393',
#   'addressLocality': 'Ribeirão Preto',
#   'name': 'Petz Ribeirão Independência',
#   'openingHours': 'Todos os dias - das 09:00 às 22:00',
#   'region': 'SP',
#   'telephone': '(16) 3602-8190'},
#  {'address': 'Av. Pres. Vargas, 2265 Jardim Santa Ângela - Ribeirão Preto/SP CEP: 14020-525',
#   'addressLocality': 'Ribeirão Preto',
#   'name': 'Petz Ribeirão Presidente Vargas',
#   'openingHours': 'Todos os dias - das 09:00 às 22:00',
#   'region': 'SP',
#   'telephone': '(16) 3602-8190'},
#  {'address': 'Av. Dr. Ricardo Jafet, 1750 Vila Mariana - São Paulo/SP CEP: 04260-000',
#   'addressLocality': 'São Paulo',
#   'name': 'Petz Ricardo Jafet',
#   'openingHours': 'Todos os dias - 24h',
#   'region': 'SP',
#   'telephone': '(11) 2181-7495'},
#  {'address': 'Avenida Presidente Kennedy, 414 Estadio - Rio Claro/SP CEP: 13501-270',
#   'addressLocality': 'Rio Claro',
#   'name': 'Petz Rio Claro',
#   'openingHours': 'Segunda a sábado - das 09:00 às 22:00\n Domingo - das 09:00 às 20:00\n Feriado - das 09:00 às 15:00',
#   'region': 'SP',
#   'telephone': '(19) 3341-7388'},
#  {'address': 'Av. República do Líbano, 251 Pina - Recife/PE CEP: 51110-131',
#   'addressLocality': 'Recife',
#   'name': 'Petz Riomar',
#   'openingHours': 'Segunda a sábado - das 10:00 às 22:00\n Domingo e Feriado - das 13:00 às 21:00',
#   'region': 'PE',
#   'telephone': '(81) 3033-7590'},
#  {'address': 'Av. Mario Leal Ferreira, 500 Bonocô - Salvador/BA CEP: 40285-600',
#   'addressLocality': 'Salvador',
#   'name': 'Petz Salvador Bonocô',
#   'openingHours': 'Todos os dias - das 08:00 às 22:00',
#   'region': 'BA',
#   'telephone': '(71) 3506-1390'},
#  {'address': 'Av. Luís Viana, 2768 Imbuí - Salvador/BA CEP: 41720-200',
#   'addressLocality': 'Salvador',
#   'name': 'Petz Salvador Paralela',
#   'openingHours': 'Todos os dias - das 08:00 às 00:00',
#   'region': 'BA',
#   'telephone': '(71) 3506-1390'},
#  {'address': 'Av. General Olímpio da Silveira, 68 Santa Cecília - São Paulo/SP CEP: 01150-000',
#   'addressLocality': 'São Paulo',
#   'name': 'Petz Santa Cecília',
#   'openingHours': 'Todos os dias - das 09:00 às 22:00',
#   'region': 'SP',
#   'telephone': '(11) 2181-7335'},
#  {'address': 'Av. Ramiro Colleoni , 355  Vila Assunção - Santo André/SP CEP: 09040-160',
#   'addressLocality': 'Santo André',
#   'name': 'Petz Santo André',
#   'openingHours': 'Todos os dias - das 09:00 às 22:00',
#   'region': 'SP',
#   'telephone': '(11) 2181-7370'},
#  {'address': 'Av. Dom Pedro II, 933 Jardim - Santo André/SP CEP: 09080-110',
#   'addressLocality': 'Santo André',
#   'name': 'Petz Santo André Dom Pedro',
#   'openingHours': 'Todos os dias - das 09:00 às 22:00',
#   'region': 'SP',
#   'telephone': '(11) 2181-7313'},
#  {'address': 'Avenida Santos Dumont, 5650 Cocó - Fortaleza/CE CEP: 60192-018',
#   'addressLocality': 'Fortaleza',
#   'name': 'Petz Santos Dumont',
#   'openingHours': 'Segunda a domingo - das 08:00 às 00:00\n Feriado - loja fechada',
#   'region': 'CE',
#   'telephone': '(85) 3031-5592'},
#  {'address': 'Rua Dr. Manoel Tourinho, 385 Macuco - Santos/SP CEP: 11015-031',
#   'addressLocality': 'Santos',
#   'name': 'Petz Santos Macuco',
#   'openingHours': 'Todos os dias - das 09:00 às 22:00',
#   'region': 'SP',
#   'telephone': '(13) 3202-7400'},
#  {'address': 'Av. Rotary, 825  - junto ao Center Castilho Centro - São Bernardo do Campo/SP CEP: 09721-000',
#   'addressLocality': 'São Bernardo do Campo',
#   'name': 'Petz São Bernardo',
#   'openingHours': 'Segunda a sexta - das 09:00 às 22:00\n Sábado - das 09:00 às 21:00\n Domingo e Feriado - das 09:00 às 17:00',
#   'region': 'SP',
#   'telephone': '(11) 2181-7420'},
#  {'address': 'Av. Francisco Pereira Lopes, 1701 Parque Maria Santa Mônica - São Carlos/SP CEP: 13561-250',
#   'addressLocality': 'São Carlos',
#   'name': 'Petz São Carlos',
#   'openingHours': 'Todos os dias - das 09:00 às 19:00',
#   'region': 'SP',
#   'telephone': '(16) 3602-8191'},
#  {'address': 'Av. Pres. Juscelino K. Oliveira, 400 Jardim Maracanã - São José do Rio Preto/SP CEP: 15092-175',
#   'addressLocality': 'São José do Rio Preto',
#   'name': 'Petz São José do Rio Preto',
#   'openingHours': 'Todos os dias - das 09:00 às 22:00',
#   'region': 'SP',
#   'telephone': '(17) 3301-2797'},
#  {'address': 'Av. São Miguel, 7988 Vila Norma - São Paulo/SP CEP: 08070-001',
#   'addressLocality': 'São Paulo',
#   'name': 'Petz São Miguel',
#   'openingHours': 'Todos os dias - das 09:00 às 22:00',
#   'region': 'SP',
#   'telephone': '(11) 21817311'},
#  {'address': 'Avenida Antônio Emmerick, 23 Vila Cascatinha - São Vicente/SP CEP: 11390-001',
#   'addressLocality': 'São Vicente',
#   'name': 'Petz São Vicente',
#   'openingHours': 'Todos os dias - das 09:00 às 22:00',
#   'region': 'SP',
#   'telephone': '(13) 3202-7400'},
#  {'address': 'Av. Nossa Senhora Aparecida, 582 Seminário - Curitiba/PR CEP: 80440-000',
#   'addressLocality': 'Curitiba',
#   'name': 'Petz Seminário',
#   'openingHours': 'Todos os dias - das 09:00 às 22:00',
#   'region': 'PR',
#   'telephone': '(41) 3528-7389'},
#  {'address': 'Avenida Eldes Scherrer Souza, 1511 Parque Res. Laranjeiras - Serra/ES CEP: 29165-680',
#   'addressLocality': 'Serra',
#   'name': 'Petz Serra',
#   'openingHours': 'Todos os dias - das 08:00 às 22:00',
#   'region': 'ES',
#   'telephone': '(27) 3022-5308'},
#  {'address': 'Avenida Raquel Teixeira Viana, 983 Canaã - Sete Lagoas/MG CEP: 35700-293',
#   'addressLocality': 'Sete Lagoas',
#   'name': 'Petz Sete Lagoas',
#   'openingHours': 'Todos os dias - das 08:00 às 22:00',
#   'region': 'MG',
#   'telephone': '(31) 3176-6017'},
#  {'address': 'R. Maria Soares Sendas, 111 Parque Barreto - São João de Meriti/RJ CEP: 25575-825',
#   'addressLocality': 'São João de Meriti',
#   'name': 'Petz Shopping Grande Rio',
#   'openingHours': 'Segunda a sábado - das 10:00 às 22:00\n Domingo e Feriado - das 13:00 às 21:00',
#   'region': 'RJ',
#   'telephone': '(21) 3161-7395'},
#  {'address': 'R. Gerôncio Thives, 1079 Barreiros - São José/SC CEP: 88117-292',
#   'addressLocality': 'São José',
#   'name': 'Petz Shopping Itaguaçu',
#   'openingHours': 'Segunda a sábado - das 10:00 às 22:00\n Domingo e Feriado - das 14:00 às 20:00',
#   'region': 'SC',
#   'telephone': '(48) 3181-0700'},
#  {'address': 'Av. Gov. Mario Covas Júnior, 01 Centro - Mauá/SP CEP: 09390-040',
#   'addressLocality': 'Mauá',
#   'name': 'Petz Shopping Mauá',
#   'openingHours': 'Segunda a sábado - das 10:00 às 22:00\n Domingo e Feriado - das 10:00 às 20:00',
#   'region': 'SP',
#   'telephone': '(11) 2181-7329'},
#  {'address': 'Q. 1 Valparaíso Shopping, S/N Parque Esplanada III - Valparaíso de Goiás/GO CEP: 72876-902',
#   'addressLocality': 'Valparaíso de Goiás',
#   'name': 'Petz Shopping Sul Valparaíso',
#   'openingHours': 'Segunda a sábado - das 10:00 às 22:00\n Domingo e Feriado - das 14:00 às 20:00',
#   'region': 'GO',
#   'telephone': '(61) 3221-7388'},
#  {'address': 'Av. Dom Aguirre, 2121 Santa Rosália - Sorocaba/SP CEP: 18035-095',
#   'addressLocality': 'Sorocaba',
#   'name': 'Petz Sorocaba',
#   'openingHours': 'Todos os dias - das 09:00 às 22:00',
#   'region': 'SP',
#   'telephone': '(15) 3331-8400'},
#  {'address': 'Avenida General Carneiro, 1120  - Loja 08 Vila Lucy - Sorocaba/SP CEP: 18043-003',
#   'addressLocality': 'Sorocaba',
#   'name': 'Petz Sorocaba Tauste',
#   'openingHours': 'Todos os dias - das 09:00 às 22:00',
#   'region': 'SP',
#   'telephone': '(15) 3331-8400'},
#  {'address': 'Av. da Amizade, 2371 Parque Euclides Miranda - Sumaré/SP CEP: 13175-646',
#   'addressLocality': 'Sumaré',
#   'name': 'Petz Sumaré',
#   'openingHours': 'Todos os dias - das 09:00 às 22:00',
#   'region': 'SP',
#   'telephone': '(19) 3341-7387'},
#  {'address': 'R. do Tesouro, 662 Taboão da Serra - São Paulo/SP CEP: 06754-190',
#   'addressLocality': 'São Paulo',
#   'name': 'Petz Taboão da Serra',
#   'openingHours': 'Todos os dias - das 09:00 às 22:00',
#   'region': 'SP',
#   'telephone': '(11) 2181-7309'},
#  {'address': 'Alameda Araguaia, 2179  - Parte A,junto à Kalunga Tamboré - Barueri/SP CEP: 06455-000',
#   'addressLocality': 'Barueri',
#   'name': 'Petz Tamboré',
#   'openingHours': 'Todos os dias - das 09:00 às 22:00',
#   'region': 'SP',
#   'telephone': '(11) 2181-7385'},
#  {'address': 'Rua Teodoro Sampaio, 1424 Pinheiros - São Paulo/SP CEP: 05406-100',
#   'addressLocality': 'São Paulo',
#   'name': 'Petz Teodoro Sampaio',
#   'openingHours': 'Todos os dias - das 09:00 às 22:00',
#   'region': 'SP',
#   'telephone': '(11) 2181-7336'},
#  {'address': 'Av. Senador Teotônio Vilela , 4482  Vila Sao Jose - São Paulo/SP CEP: 04864-001',
#   'addressLocality': 'São Paulo',
#   'name': 'Petz Teotônio Vilela',
#   'openingHours': 'Todos os dias - das 09:00 às 22:00',
#   'region': 'SP',
#   'telephone': '(11) 2181-7312'},
#  {'address': 'Av. Tucuruvi, 220 Tucuruvi - São Paulo/SP CEP: 02305-002',
#   'addressLocality': 'São Paulo',
#   'name': 'Petz Trimais',
#   'openingHours': 'Segunda a sábado - das 09:00 às 21:00\n Domingo - das 09:00 às 19:00\n Feriado - das 09:00 às 20:00',
#   'region': 'SP',
#   'telephone': '(11) 2181-7334'},
#  {'address': 'Av. Leopoldino de Oliveira, 4001 Estados Unidos - Uberaba/MG CEP: 38010-000',
#   'addressLocality': 'Uberaba',
#   'name': 'Petz Uberaba',
#   'openingHours': 'Segunda a sexta - das 08:00 às 21:00\n Sábado - das 08:00 às 18:00\n Domingo e Feriado - das 08:00 às 12:00',
#   'region': 'MG',
#   'telephone': '(34) 3480-3876'},
#  {'address': 'Av. Rondon Pacheco, 505 Tabajaras - Uberlândia/MG CEP: 38400-242',
#   'addressLocality': 'Uberlândia',
#   'name': 'Petz Uberlândia',
#   'openingHours': 'Segunda-feira - das 08:00 às 21:00\n Terça-feira - das 08:00 às 22:00\n Quarta-feira - das 08:00 às 22:00\n Quinta-feira - das 08:00 às 22:00\n Sexta-feira - das 08:00 às 22:00\n Sábado - das 08:00 às 22:00\n Domingo - das 08:00 às 22:00\n Feriado - das 08:00 às 22:00',
#   'region': 'MG',
#   'telephone': '(34) 3306-9093'},
#  {'address': 'Av. Professor Vicente Rao, 1700 Jardim Petropolis - São Paulo/SP CEP: 04636-001',
#   'addressLocality': 'São Paulo',
#   'name': 'Petz Vicente Rao',
#   'openingHours': 'Todos os dias - das 09:00 às 22:00',
#   'region': 'SP',
#   'telephone': '(11) 2181-7331'},
#  {'address': 'R. Maria Primo de Jesus, 47/69 Vila Galvão - Guarulhos/SP CEP: 07056-040',
#   'addressLocality': 'Guarulhos',
#   'name': 'Petz Vila Galvão',
#   'openingHours': 'Todos os dias - das 09:00 às 22:00',
#   'region': 'SP',
#   'telephone': '(11) 2181-7338'},
#  {'address': 'Rua Teodoro da Silva, 668 Vila Isabel - Rio de Janeiro/RJ CEP: 20560-025',
#   'addressLocality': 'Rio de Janeiro',
#   'name': 'Petz Vila Isabel',
#   'openingHours': 'Todos os dias - das 08:00 às 22:00',
#   'region': 'RJ',
#   'telephone': '(21) 3161-7391'},
#  {'address': 'Rua Vergueiro, 2604 Vila Mariana - São Paulo/SP CEP: 04102-000',
#   'addressLocality': 'São Paulo',
#   'name': 'Petz Vila Mariana',
#   'openingHours': 'Todos os dias - das 09:00 às 22:00',
#   'region': 'SP',
#   'telephone': '(11) 2181-7322'},
#  {'address': 'Avenida Conde de Frontin, 2416 Tatuapé - São Paulo/SP CEP: 03501-000',
#   'addressLocality': 'São Paulo',
#   'name': 'Petz Vila Matilde',
#   'openingHours': 'Todos os dias - das 09:00 às 22:00',
#   'region': 'SP',
#   'telephone': '(11) 2181-7319'},
#  {'address': 'Rodovia do Sol, 256 Itapuã - Vila Velha/ES CEP: 29102-320',
#   'addressLocality': 'Vila Velha',
#   'name': 'Petz Vila Velha',
#   'openingHours': 'Segunda a domingo - das 08:00 às 22:00\n Feriado - das 08:00 às 18:00',
#   'region': 'ES',
#   'telephone': '(27) 3022-5308'},
#  {'address': 'Av. Nossa Senhora da Penha, 1819 Santa Lucia - Vitória/ES CEP: 29056-075',
#   'addressLocality': 'Vitória',
#   'name': 'Petz Vitória',
#   'openingHours': 'Segunda a domingo - das 08:00 às 00:00\n Feriado - das 08:00 às 18:00',
#   'region': 'ES',
#   'telephone': '(27) 3022-5308'},
#  {'address': 'Av. Washington Luís, 2737 Brooklin - São Paulo/SP CEP: 04626-000',
#   'addressLocality': 'São Paulo',
#   'name': 'Petz Washington Luís',
#   'openingHours': 'Todos os dias - das 09:00 às 00:00',
#   'region': 'SP',
#   'telephone': '(11) 2181-7485'},
#  {'address': 'Av. Washington Soares, 2300 Edson Queiroz - Fortaleza/CE CEP: 60810-350',
#   'addressLocality': 'Fortaleza',
#   'name': 'Petz Washington Soares',
#   'openingHours': 'Todos os dias - das 09:00 às 22:00',
#   'region': 'CE',
#   'telephone': '(85) 3031-5592'}]

# %%
import csv	
keys = stores[0].keys()	 
with open('stores.csv', 'w', newline='')  as output_file:	     
	dict_writer = csv.DictWriter(output_file, keys)	     
	dict_writer.writeheader()
	dict_writer.writerows(stores)
